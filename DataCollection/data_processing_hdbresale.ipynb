# %% [markdown]
# ### Initial Cleaning of HDB Resale Dataset -- Before Feature Extraction ###

# %%
import pandas as pd
import json
import pickle
from sklearn.preprocessing import LabelEncoder
from category_encoders import TargetEncoder

# Load dataset
file_path = "Data_Raw/ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv"  # Adjust if needed
df = pd.read_csv(file_path)

# Step 1: Convert 'month' to separate year and month columns
df['month'] = pd.to_datetime(df['month'])
df.insert(df.columns.get_loc('month') + 1, 'year', df['month'].dt.year)
df['month'] = df['month'].dt.month

# Step 2: Encode Categorical Variables - Label Encoding (For Tree-Based Models)
categorical_cols = ["town", "flat_type", "flat_model"]
label_encoders = {}
encoded_mappings = {}

df_encoded = df.copy()

for col in categorical_cols:
    le = LabelEncoder()
    label_encoded_col = col + "_LE"
    df_encoded.insert(df_encoded.columns.get_loc(col) + 1, label_encoded_col, le.fit_transform(df_encoded[col]))
    label_encoders[col] = le
    encoded_mappings[col] = dict(zip(le.classes_, le.transform(le.classes_)))

# Step 3: Target Encoding (For Models that Benefit from It)
target_col = 'resale_price'

df_encoded[categorical_cols] = df_encoded[categorical_cols].astype(str)
encoder = TargetEncoder(cols=categorical_cols)
encoder.fit(df_encoded[categorical_cols], df_encoded[target_col])

target_encoded_values = encoder.transform(df_encoded[categorical_cols])
target_encoded_values.columns = [f"{col}_TE" for col in categorical_cols]

# Insert TE columns after corresponding LE columns
for col in categorical_cols:
    le_col = col + "_LE"
    te_col = col + "_TE"
    df_encoded.insert(df_encoded.columns.get_loc(le_col) + 1, te_col, target_encoded_values[te_col])

# Step 4: Map 'storey_range' to Numeric Values
storey_mapping = {
    "01 TO 03": 1, "04 TO 06": 2, "07 TO 09": 3, "10 TO 12": 4, "13 TO 15": 5, 
    "16 TO 18": 6, "19 TO 21": 7, "22 TO 24": 8, "25 TO 27": 9, "28 TO 30": 10, 
    "31 TO 33": 11, "34 TO 36": 12, "37 TO 39": 13, "40 TO 42": 14, "43 TO 45": 15, 
    "46 TO 48": 16, "49 TO 51": 17
}
df_encoded.insert(df_encoded.columns.get_loc("storey_range") + 1, "storey_range_LE", df_encoded["storey_range"].map(storey_mapping))

# Step 5: Calculating price_per_sqm
df_encoded.insert(df_encoded.columns.get_loc('floor_area_sqm') + 1, 'price_per_sqm', df_encoded['resale_price'] / df_encoded['floor_area_sqm'])

# Step 6: Save Cleaned Data
df_encoded.to_csv("Data/HDBResale_cleaned.csv", index=False)

# Print confirmation of saved data
print("\n✅ Data saved at: Data/HDBResale_cleaned.csv")

# Save LabelEncoders in JSON
decoded_mappings = {col: {str(k): int(v) for k, v in mapping.items()} for col, mapping in encoded_mappings.items()}
with open("label_encoders.json", "w") as f:
    json.dump(decoded_mappings, f, indent=4)

# Print confirmation of saved data
print("✅ Label encoders saved at: label_encoders.json")

# %% [markdown]
# ### Feature Engineering - Geocoding ###

# %%
import pandas as pd
import requests
import time

# Load dataset
file_path = "Data/HDBResale_cleaned.csv"
df = pd.read_csv(file_path)

# Ensure the required columns exist
if "block" not in df.columns or "street_name" not in df.columns:
    raise ValueError("Dataset must contain 'block' and 'street_name' columns.")

# Local Nominatim instance URL
NOMINATIM_URL = "http://localhost:8080/search"

# Function to get coordinates from Nominatim
def get_coordinates(address):
    print(f"Geocoding - {address}")
    params = {"q": address, "format": "json"}
    response = requests.get(NOMINATIM_URL, params=params)
    
    if response.status_code == 200:
        data = response.json()
        if data:
            return data[0]["lat"], data[0]["lon"]  # Return latitude, longitude
    return None, None  # Return None if no result

# Apply geocoding to each row
df["Latitude"], df["Longitude"] = zip(*df.apply(lambda row: get_coordinates(f"{row['block']} {row['street_name']}"), axis=1))

# Save the new dataset with coordinates
output_file = "HDBResale_with_coordinates.csv"
df.to_csv(output_file, index=False)

print(f"Geocoded dataset saved as: {output_file}")

# %%
import pandas as pd
import requests
import time

# Load dataset
file_path = "HDBResale_with_coordinates.csv"
df = pd.read_csv(file_path)

# Ensure the required columns exist
if "block" not in df.columns or "street_name" not in df.columns:
    raise ValueError("Dataset must contain 'block' and 'street_name' columns.")

# Ensure Latitude and Longitude columns exist
if "Latitude" not in df.columns or "Longitude" not in df.columns:
    df["Latitude"], df["Longitude"] = None, None  # Create empty columns if they don't exist

# Local Nominatim instance URL
NOMINATIM_URL = "http://localhost:8080/search"

# Function to get coordinates from Nominatim
def get_coordinates(address):
    print(f"Geocoding - {address}")
    params = {"q": address, "format": "json"}
    
    try:
        response = requests.get(NOMINATIM_URL, params=params, timeout=5)
        if response.status_code == 200:
            data = response.json()
            if data:
                return data[0]["lat"], data[0]["lon"]  # Return latitude, longitude
    except requests.exceptions.RequestException as e:
        print(f"Error with request: {e}")
    
    return None, None  # Return None if no result

# Process only rows with missing coordinates
for index, row in df.iterrows():
    if pd.isna(row["Latitude"]) or pd.isna(row["Longitude"]):
        address = f"{row['block']} {row['street_name']}"
        lat, lon = get_coordinates(address)
        
        # Save new coordinates if found
        df.at[index, "Latitude"] = lat
        df.at[index, "Longitude"] = lon

        # Optional: Introduce a short delay to prevent excessive requests
        # time.sleep(1)

# Save the updated dataset
output_file = "HDBResale_with_coordinates.csv"
df.to_csv(output_file, index=False)

print(f"Geocoded dataset saved as: {output_file}")
# Out:
# Geocoding - 101 BEDOK NORTH AVE 4
# Geocoding - 548 BEDOK NORTH AVE 1
# Geocoding - 75 BEDOK NORTH RD
# Geocoding - 550 BEDOK NORTH AVE 1
# Geocoding - 528 BEDOK NORTH ST 3
# Geocoding - 534 BEDOK NORTH ST 3
# Geocoding - 550 BEDOK NORTH AVE 1
# Geocoding - 77 BEDOK NORTH RD
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23940\3331134679.py:43: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.33446945' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[index, "Latitude"] = lat
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23940\3331134679.py:44: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '103.93793810303602' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[index, "Longitude"] = lon
# Geocoding - 57 NEW UPPER CHANGI RD
# Geocoding - 57 NEW UPPER CHANGI RD
# Geocoding - 105 BEDOK NORTH AVE 4
# Geocoding - 75 BEDOK NORTH RD
# Geocoding - 425 BEDOK NORTH RD
# Geocoding - 117 BEDOK NORTH RD
# Geocoding - 423 BEDOK NORTH AVE 1
# Geocoding - 533 BEDOK NORTH ST 3
# Geocoding - 80 BEDOK NORTH RD
# Geocoding - 78 BEDOK NORTH RD
# Geocoding - 81 BEDOK NORTH RD
# Geocoding - 124 BEDOK NORTH RD
# Geocoding - 705 BEDOK NORTH RD
# Geocoding - 554 BEDOK NORTH ST 3
# Geocoding - 81 BEDOK NORTH RD
# Geocoding - 508 BEDOK NORTH AVE 3
# Geocoding - 185 BEDOK NORTH RD
# Geocoding - 220B BEDOK CENTRAL
# Geocoding - 415 BEDOK NORTH AVE 2
# Geocoding - 219C BEDOK CENTRAL
# Geocoding - 94C BEDOK NORTH AVE 4
# Geocoding - 342 BUKIT BATOK ST 34
# Geocoding - 530 BUKIT BATOK ST 51
# Geocoding - 145 BUKIT BATOK ST 11
# Geocoding - 528 BUKIT BATOK ST 51
# Geocoding - 537 BUKIT BATOK ST 52
# Geocoding - 213 BUKIT BATOK ST 21
# Geocoding - 219 BUKIT BATOK ST 21
# Geocoding - 235 BUKIT BATOK EAST AVE 5
# Geocoding - 130 BUKIT BATOK WEST AVE 6
# Geocoding - 212 BUKIT BATOK ST 21
# Geocoding - 346 BUKIT BATOK ST 34
# Geocoding - 219 BUKIT BATOK ST 21
# Geocoding - 226 BUKIT BATOK CENTRAL
# Geocoding - 247 BUKIT BATOK EAST AVE 5
# Geocoding - 169 BUKIT BATOK WEST AVE 8
# Geocoding - 154 BUKIT BATOK ST 11
# Geocoding - 260 BUKIT BATOK EAST AVE 4
# Geocoding - 360 BUKIT BATOK ST 31
# Geocoding - 217 BUKIT BATOK ST 21
# Geocoding - 178 BUKIT BATOK WEST AVE 8
# Geocoding - 169 BUKIT BATOK WEST AVE 8
# Geocoding - 265 BUKIT BATOK EAST AVE 4
# Geocoding - 134 BUKIT BATOK WEST AVE 6
# Geocoding - 301 BUKIT BATOK ST 31
# Geocoding - 537 BUKIT BATOK ST 52
# Geocoding - 289E BUKIT BATOK ST 25
# Geocoding - 244 BUKIT BATOK EAST AVE 5
# Geocoding - 248 BUKIT BATOK EAST AVE 5
# Geocoding - 290D BUKIT BATOK EAST AVE 3
# Geocoding - 395 BUKIT BATOK WEST AVE 5
# Geocoding - 642 BUKIT BATOK CENTRAL
# Geocoding - 185 BUKIT BATOK WEST AVE 6
# Geocoding - 106 BUKIT BATOK CENTRAL
# Geocoding - 210 BUKIT BATOK ST 21
# Geocoding - 386 BUKIT BATOK WEST AVE 5
# Geocoding - 394 BUKIT BATOK WEST AVE 5
# Geocoding - 190 BUKIT BATOK WEST AVE 6
# Geocoding - 206 BUKIT BATOK ST 21
# Geocoding - 211 BUKIT BATOK ST 21
# Geocoding - 391 BUKIT BATOK WEST AVE 5
# Geocoding - 205 BUKIT BATOK ST 21
# Geocoding - 193 BUKIT BATOK WEST AVE 6
# Geocoding - 624 BUKIT BATOK CENTRAL
# Geocoding - 290A BUKIT BATOK ST 24
# Geocoding - 141 BUKIT BATOK ST 11
# Geocoding - 120 BUKIT BATOK CENTRAL
# Geocoding - 289A BUKIT BATOK ST 25
# Geocoding - 10 JALAN BUKIT HO SWEE
# Geocoding - 2 JALAN BUKIT HO SWEE
# Geocoding - 142 JALAN BUKIT MERAH
# Geocoding - 131 JALAN BUKIT MERAH
# Geocoding - 142 JALAN BUKIT MERAH
# Geocoding - 116 BUKIT MERAH VIEW
# Geocoding - 131 JALAN BUKIT MERAH
# Geocoding - 130 BUKIT MERAH VIEW
# Geocoding - 122 BUKIT MERAH LANE 1
# Geocoding - 115 BUKIT PURMEI RD
# Geocoding - 108 BUKIT PURMEI RD
# Geocoding - 38 JALAN RUMAH TINGGI
# Geocoding - 38 JALAN RUMAH TINGGI
# Geocoding - 134 JALAN BUKIT MERAH
# Geocoding - 27A JALAN MEMBINA
# Geocoding - 27A JALAN MEMBINA
# Geocoding - 27A JALAN MEMBINA
# Geocoding - 35 JALAN RUMAH TINGGI
# Geocoding - 237 BUKIT PANJANG RING RD
# Geocoding - 539 BUKIT PANJANG RING RD
# Geocoding - 539 BUKIT PANJANG RING RD
# Geocoding - 537 BUKIT PANJANG RING RD
# Geocoding - 242 BUKIT PANJANG RING RD
# Geocoding - 613 BUKIT PANJANG RING RD
# Geocoding - 9 JALAN KUKOH
# Geocoding - 5 TG PAGAR PLAZA
# Geocoding - 229 CHOA CHU KANG CENTRAL
# Geocoding - 237 CHOA CHU KANG CENTRAL
# Geocoding - 157 JALAN TECK WHYE
# Geocoding - 239 CHOA CHU KANG CENTRAL
# Geocoding - 635 CHOA CHU KANG NORTH 6
# Geocoding - 353 CHOA CHU KANG CENTRAL
# Geocoding - 353 CHOA CHU KANG CENTRAL
# Geocoding - 760 CHOA CHU KANG NORTH 5
# Geocoding - 789 CHOA CHU KANG NORTH 6
# Geocoding - 411 COMMONWEALTH AVE WEST
# Geocoding - 120 GEYLANG EAST CENTRAL
# Geocoding - 135 LORONG AH SOO
# Geocoding - 142 LORONG AH SOO
# Geocoding - 465 UPPER SERANGOON RD
# Geocoding - 835 HOUGANG CENTRAL
# Geocoding - 136 LORONG AH SOO
# Geocoding - 682C JURONG WEST CENTRAL 1
# Geocoding - 681C JURONG WEST CENTRAL 1
# Geocoding - 683A JURONG WEST CENTRAL 1
# Geocoding - 27 JALAN BAHAGIA
# Geocoding - 76 LORONG LIMAU
# Geocoding - 11 UPPER BOON KENG RD
# Geocoding - 16 UPPER BOON KENG RD
# Geocoding - 468 NORTH BRIDGE RD
# Geocoding - 5A UPPER BOON KENG RD
# Geocoding - 18 JALAN TENTERAM
# Geocoding - 3C UPPER BOON KENG RD
# Geocoding - 105 JALAN RAJAH
# Geocoding - 293 PUNGGOL CENTRAL
# Geocoding - 602A PUNGGOL CENTRAL
# Geocoding - 601A PUNGGOL CENTRAL
# Geocoding - 601C PUNGGOL CENTRAL
# Geocoding - 601C PUNGGOL CENTRAL
# Geocoding - 161B PUNGGOL CENTRAL
# Geocoding - 166B PUNGGOL CENTRAL
# Geocoding - 163A PUNGGOL CENTRAL
# Geocoding - 295 PUNGGOL CENTRAL
# Geocoding - 299 PUNGGOL CENTRAL
# Geocoding - 83 COMMONWEALTH CL
# Geocoding - 81 COMMONWEALTH CL
# Geocoding - 109 COMMONWEALTH CRES
# Geocoding - 94 COMMONWEALTH DR
# Geocoding - 111 COMMONWEALTH CRES
# Geocoding - 83 COMMONWEALTH CL
# Geocoding - 82 COMMONWEALTH CL
# Geocoding - 86 COMMONWEALTH CL
# Geocoding - 446C JALAN KAYU
# Geocoding - 272D SENGKANG CENTRAL
# Geocoding - 272B SENGKANG CENTRAL
# Geocoding - 271C SENGKANG CENTRAL
# Geocoding - 4 LORONG LEW LIAN
# Geocoding - 4 LORONG LEW LIAN
# Geocoding - 2 LORONG LEW LIAN
# Geocoding - 101 SERANGOON NORTH AVE 1
# Geocoding - 144 SERANGOON NORTH AVE 1
# Geocoding - 109 SERANGOON NORTH AVE 1
# Geocoding - 420 SERANGOON CENTRAL
# Geocoding - 506 SERANGOON NORTH AVE 4
# Geocoding - 542 SERANGOON NORTH AVE 4
# Geocoding - 537 SERANGOON NORTH AVE 4
# Geocoding - 525 SERANGOON NORTH AVE 4
# Geocoding - 518A TAMPINES CENTRAL 7
# Geocoding - 518B TAMPINES CENTRAL 7
# Geocoding - 55 LORONG 5 TOA PAYOH
# Geocoding - 9 LORONG 7 TOA PAYOH
# Geocoding - 66 LORONG 4 TOA PAYOH
# Geocoding - 163 LORONG 1 TOA PAYOH
# Geocoding - 13 LORONG 7 TOA PAYOH
# Geocoding - 108 LORONG 1 TOA PAYOH
# Geocoding - 20 LORONG 7 TOA PAYOH
# Geocoding - 203 TOA PAYOH NORTH
# Geocoding - 34 LORONG 5 TOA PAYOH
# Geocoding - 114 LORONG 1 TOA PAYOH
# Geocoding - 232 LORONG 8 TOA PAYOH
# Geocoding - 199 TOA PAYOH NORTH
# Geocoding - 91 LORONG 3 TOA PAYOH
# Geocoding - 123 LORONG 1 TOA PAYOH
# Geocoding - 53 LORONG 5 TOA PAYOH
# Geocoding - 157 LORONG 1 TOA PAYOH
# Geocoding - 143 LORONG 2 TOA PAYOH
# Geocoding - 81A LORONG 4 TOA PAYOH
# Geocoding - 121 LORONG 2 TOA PAYOH
# Geocoding - 144 LORONG 2 TOA PAYOH
# Geocoding - 145 LORONG 2 TOA PAYOH
# Geocoding - 79E TOA PAYOH CENTRAL
# Geocoding - 79C TOA PAYOH CENTRAL
# Geocoding - 223 LORONG 8 TOA PAYOH
# Geocoding - 141 LORONG 2 TOA PAYOH
# Geocoding - 81 LORONG 4 TOA PAYOH
# Geocoding - 302 YISHUN CENTRAL
# Geocoding - 322 YISHUN CENTRAL
# Geocoding - 541 BEDOK NORTH ST 3
# Geocoding - 534 BEDOK NORTH ST 3
# Geocoding - 105 BEDOK NORTH AVE 4
# Geocoding - 501 BEDOK NORTH ST 3
# Geocoding - 57 NEW UPPER CHANGI RD
# Geocoding - 540 BEDOK NORTH ST 3
# Geocoding - 529 BEDOK NORTH ST 3
# Geocoding - 134 BEDOK NORTH ST 2
# Geocoding - 501 BEDOK NORTH ST 3
# Geocoding - 28 NEW UPPER CHANGI RD
# Geocoding - 126 BEDOK NORTH ST 2
# Geocoding - 528 BEDOK NORTH ST 3
# Geocoding - 536 BEDOK NORTH ST 3
# Geocoding - 122 BEDOK NORTH ST 2
# Geocoding - 528 BEDOK NORTH ST 3
# Geocoding - 107 BEDOK NORTH RD
# Geocoding - 545 BEDOK NORTH ST 3
# Geocoding - 214 BEDOK NORTH ST 1
# Geocoding - 525 BEDOK NORTH ST 3
# Geocoding - 526 BEDOK NORTH ST 3
# Geocoding - 201 BEDOK NORTH ST 1
# Geocoding - 420 BEDOK NORTH ST 1
# Geocoding - 219D BEDOK CENTRAL
# Geocoding - 95 BEDOK NORTH AVE 4
# Geocoding - 51 NEW UPPER CHANGI RD
# Geocoding - 524 BEDOK NORTH ST 3
# Geocoding - 421 BEDOK NORTH RD
# Geocoding - 404 BEDOK NORTH AVE 3
# Geocoding - 181 BEDOK NORTH RD
# Geocoding - 180 BEDOK NORTH RD
# Geocoding - 185 BEDOK NORTH RD
# Geocoding - 91 BEDOK NORTH ST 4
# Geocoding - 549 BEDOK NORTH AVE 1
# Geocoding - 60 NEW UPPER CHANGI RD
# Geocoding - 405 BEDOK NORTH AVE 3
# Geocoding - 167 BUKIT BATOK WEST AVE 8
# Geocoding - 533 BUKIT BATOK ST 51
# Geocoding - 505 BUKIT BATOK ST 52
# Geocoding - 265 BUKIT BATOK EAST AVE 4
# Geocoding - 173 BUKIT BATOK WEST AVE 8
# Geocoding - 239 BUKIT BATOK EAST AVE 5
# Geocoding - 533 BUKIT BATOK ST 51
# Geocoding - 411 BUKIT BATOK WEST AVE 4
# Geocoding - 136 BUKIT BATOK WEST AVE 6
# Geocoding - 235 BUKIT BATOK EAST AVE 5
# Geocoding - 239 BUKIT BATOK EAST AVE 5
# Geocoding - 138 BUKIT BATOK WEST AVE 6
# Geocoding - 130 BUKIT BATOK WEST AVE 6
# Geocoding - 163 BUKIT BATOK ST 11
# Geocoding - 206 BUKIT BATOK ST 21
# Geocoding - 301 BUKIT BATOK ST 31
# Geocoding - 162 BUKIT BATOK ST 11
# Geocoding - 501 BUKIT BATOK ST 52
# Geocoding - 340 BUKIT BATOK ST 34
# Geocoding - 288E BUKIT BATOK ST 25
# Geocoding - 394 BUKIT BATOK WEST AVE 5
# Geocoding - 202 BUKIT BATOK ST 21
# Geocoding - 393 BUKIT BATOK WEST AVE 5
# Geocoding - 290D BUKIT BATOK EAST AVE 3
# Geocoding - 288A BUKIT BATOK ST 25
# Geocoding - 117 BUKIT BATOK WEST AVE 6
# Geocoding - 103 BUKIT BATOK CENTRAL
# Geocoding - 221 BUKIT BATOK EAST AVE 3
# Geocoding - 137 JALAN BUKIT MERAH
# Geocoding - 109 BUKIT PURMEI RD
# Geocoding - 28 JALAN BUKIT MERAH
# Geocoding - 2 JALAN BUKIT MERAH
# Geocoding - 26 JALAN KLINIK
# Geocoding - 103 BUKIT PURMEI RD
# Geocoding - 119 BUKIT MERAH VIEW
# Geocoding - 129 BUKIT MERAH VIEW
# Geocoding - 111 BUKIT PURMEI RD
# Geocoding - 38 JALAN RUMAH TINGGI
# Geocoding - 21 JALAN MEMBINA
# Geocoding - 23 JALAN MEMBINA
# Geocoding - 19 JALAN MEMBINA
# Geocoding - 447 BUKIT PANJANG RING RD
# Geocoding - 244 BUKIT PANJANG RING RD
# Geocoding - 537 BUKIT PANJANG RING RD
# Geocoding - 4 TG PAGAR PLAZA
# Geocoding - 532 UPPER CROSS ST
# Geocoding - 152 JALAN TECK WHYE
# Geocoding - 216 CHOA CHU KANG CENTRAL
# Geocoding - 790 CHOA CHU KANG NORTH 6
# Geocoding - 765 CHOA CHU KANG NORTH 5
# Geocoding - 634 CHOA CHU KANG NORTH 6
# Geocoding - 227 CHOA CHU KANG CENTRAL
# Geocoding - 213 CHOA CHU KANG CENTRAL
# Geocoding - 163 JALAN TECK WHYE
# Geocoding - 207 CHOA CHU KANG CENTRAL
# Geocoding - 410 COMMONWEALTH AVE WEST
# Geocoding - 135 LORONG AH SOO
# Geocoding - 835 HOUGANG CENTRAL
# Geocoding - 835 HOUGANG CENTRAL
# Geocoding - 838 HOUGANG CENTRAL
# Geocoding - 852 HOUGANG CENTRAL
# Geocoding - 687 JURONG WEST CENTRAL 1
# Geocoding - 681B JURONG WEST CENTRAL 1
# Geocoding - 687 JURONG WEST CENTRAL 1
# Geocoding - 28 JALAN BAHAGIA
# Geocoding - 35 JALAN BAHAGIA
# Geocoding - 76 LORONG LIMAU
# Geocoding - 11 UPPER BOON KENG RD
# Geocoding - 16 UPPER BOON KENG RD
# Geocoding - 11 UPPER BOON KENG RD
# Geocoding - 101 JALAN RAJAH
# Geocoding - 2B UPPER BOON KENG RD
# Geocoding - 2A UPPER BOON KENG RD
# Geocoding - 3B UPPER BOON KENG RD
# Geocoding - 601C PUNGGOL CENTRAL
# Geocoding - 303B PUNGGOL CENTRAL
# Geocoding - 649 PUNGGOL CENTRAL
# Geocoding - 160A PUNGGOL CENTRAL
# Geocoding - 294 PUNGGOL CENTRAL
# Geocoding - 298 PUNGGOL CENTRAL
# Geocoding - 190 PUNGGOL CENTRAL
# Geocoding - 92 COMMONWEALTH DR
# Geocoding - 81 COMMONWEALTH CL
# Geocoding - 270A SENGKANG CENTRAL
# Geocoding - 272C SENGKANG CENTRAL
# Geocoding - 108 SERANGOON NORTH AVE 1
# Geocoding - 113 SERANGOON NORTH AVE 1
# Geocoding - 105 SERANGOON NORTH AVE 1
# Geocoding - 153 SERANGOON NORTH AVE 1
# Geocoding - 253 SERANGOON CENTRAL DR
# Geocoding - 203 SERANGOON CENTRAL
# Geocoding - 103 SERANGOON NORTH AVE 1
# Geocoding - 109 SERANGOON NORTH AVE 1
# Geocoding - 126 SERANGOON NORTH AVE 1
# Geocoding - 528 SERANGOON NORTH AVE 4
# Geocoding - 528 SERANGOON NORTH AVE 4
# Geocoding - 554 SERANGOON NORTH AVE 3
# Geocoding - 505 SERANGOON NORTH AVE 4
# Geocoding - 512 SERANGOON NORTH AVE 4
# Geocoding - 552 SERANGOON NORTH AVE 3
# Geocoding - 123 SERANGOON NORTH AVE 1
# Geocoding - 123 SERANGOON NORTH AVE 1
# Geocoding - 526 SERANGOON NORTH AVE 4
# Geocoding - 525 SERANGOON NORTH AVE 4
# Geocoding - 423 SERANGOON CENTRAL
# Geocoding - 518B TAMPINES CENTRAL 7
# Geocoding - 52 LORONG 6 TOA PAYOH
# Geocoding - 52 LORONG 6 TOA PAYOH
# Geocoding - 69 LORONG 4 TOA PAYOH
# Geocoding - 12 LORONG 7 TOA PAYOH
# Geocoding - 53 LORONG 5 TOA PAYOH
# Geocoding - 119 LORONG 1 TOA PAYOH
# Geocoding - 163 LORONG 1 TOA PAYOH
# Geocoding - 110 LORONG 1 TOA PAYOH
# Geocoding - 232 LORONG 8 TOA PAYOH
# Geocoding - 53 LORONG 5 TOA PAYOH
# Geocoding - 124 LORONG 1 TOA PAYOH
# Geocoding - 96 LORONG 3 TOA PAYOH
# Geocoding - 119 LORONG 1 TOA PAYOH
# Geocoding - 232 LORONG 8 TOA PAYOH
# Geocoding - 157 LORONG 1 TOA PAYOH
# Geocoding - 85B LORONG 4 TOA PAYOH
# Geocoding - 85C LORONG 4 TOA PAYOH
# Geocoding - 227 LORONG 8 TOA PAYOH
# Geocoding - 144 LORONG 2 TOA PAYOH
# Geocoding - 37 LORONG 5 TOA PAYOH
# Geocoding - 153A LORONG 1 TOA PAYOH
# Geocoding - 79B TOA PAYOH CENTRAL
# Geocoding - 81B LORONG 4 TOA PAYOH
# Geocoding - 146 LORONG 2 TOA PAYOH
# Geocoding - 155 LORONG 1 TOA PAYOH
# Geocoding - 229 LORONG 8 TOA PAYOH
# Geocoding - 36 LORONG 5 TOA PAYOH
# Geocoding - 35 LORONG 5 TOA PAYOH
# Geocoding - 153A LORONG 1 TOA PAYOH
# Geocoding - 79C TOA PAYOH CENTRAL
# Geocoding - 81 LORONG 4 TOA PAYOH
# Geocoding - 237 LORONG 1 TOA PAYOH
# Geocoding - 75 BEDOK NORTH RD
# Geocoding - 539 BEDOK NORTH ST 3
# Geocoding - 28 NEW UPPER CHANGI RD
# Geocoding - 501 BEDOK NORTH ST 3
# Geocoding - 550 BEDOK NORTH AVE 1
# Geocoding - 504 BEDOK NORTH ST 3
# Geocoding - 526 BEDOK NORTH ST 3
# Geocoding - 529 BEDOK NORTH ST 3
# Geocoding - 530 BEDOK NORTH ST 3
# Geocoding - 534 BEDOK NORTH ST 3
# Geocoding - 74 BEDOK NORTH RD
# Geocoding - 29 NEW UPPER CHANGI RD
# Geocoding - 534 BEDOK NORTH ST 3
# Geocoding - 30 NEW UPPER CHANGI RD
# Geocoding - 30 NEW UPPER CHANGI RD
# Geocoding - 424 BEDOK NORTH AVE 1
# Geocoding - 525 BEDOK NORTH ST 3
# Geocoding - 110 BEDOK NORTH RD
# Geocoding - 126 BEDOK NORTH ST 2
# Geocoding - 521 BEDOK NORTH AVE 1
# Geocoding - 125 BEDOK NORTH RD
# Geocoding - 77 BEDOK NORTH RD
# Geocoding - 27 NEW UPPER CHANGI RD
# Geocoding - 419 BEDOK NORTH ST 1
# Geocoding - 425 BEDOK NORTH RD
# Geocoding - 204 BEDOK NORTH ST 1
# Geocoding - 74 BEDOK NORTH RD
# Geocoding - 425 BEDOK NORTH RD
# Geocoding - 104 BEDOK NORTH AVE 4
# Geocoding - 122 BEDOK NORTH ST 2
# Geocoding - 418 BEDOK NORTH AVE 2
# Geocoding - 202 BEDOK NORTH ST 1
# Geocoding - 540 BEDOK NORTH ST 3
# Geocoding - 214 BEDOK NORTH ST 1
# Geocoding - 416 BEDOK NORTH AVE 2
# Geocoding - 419 BEDOK NORTH ST 1
# Geocoding - 122 BEDOK NORTH ST 2
# Geocoding - 221B BEDOK CENTRAL
# Geocoding - 52 NEW UPPER CHANGI RD
# Geocoding - 512 BEDOK NORTH AVE 2
# Geocoding - 124 BEDOK NORTH RD
# Geocoding - 707 BEDOK NORTH RD
# Geocoding - 530 BEDOK NORTH ST 3
# Geocoding - 134 BEDOK NORTH ST 2
# Geocoding - 404 BEDOK NORTH AVE 3
# Geocoding - 64 NEW UPPER CHANGI RD
# Geocoding - 507 BEDOK NORTH AVE 3
# Geocoding - 428 BEDOK NORTH RD
# Geocoding - 183 BEDOK NORTH RD
# Geocoding - 221A BEDOK CENTRAL
# Geocoding - 182 BEDOK NORTH RD
# Geocoding - 221C BEDOK CENTRAL
# Geocoding - 428 BEDOK NORTH RD
# Geocoding - 139 BEDOK NORTH AVE 3
# Geocoding - 99 BEDOK NORTH AVE 4
# Geocoding - 552 BEDOK NORTH AVE 1
# Geocoding - 139 BEDOK NORTH AVE 3
# Geocoding - 407 BEDOK NORTH AVE 3
# Geocoding - 405 BEDOK NORTH AVE 3
# Geocoding - 61 NEW UPPER CHANGI RD
# Geocoding - 420 BUKIT BATOK WEST AVE 2
# Geocoding - 267 BUKIT BATOK EAST AVE 4
# Geocoding - 523 BUKIT BATOK ST 52
# Geocoding - 283 BUKIT BATOK EAST AVE 3
# Geocoding - 271 BUKIT BATOK EAST AVE 4
# Geocoding - 272 BUKIT BATOK EAST AVE 4
# Geocoding - 316 BUKIT BATOK ST 32
# Geocoding - 283 BUKIT BATOK EAST AVE 3
# Geocoding - 160 BUKIT BATOK ST 11
# Geocoding - 229 BUKIT BATOK EAST AVE 3
# Geocoding - 411 BUKIT BATOK WEST AVE 4
# Geocoding - 417 BUKIT BATOK WEST AVE 4
# Geocoding - 175 BUKIT BATOK WEST AVE 8
# Geocoding - 180 BUKIT BATOK WEST AVE 8
# Geocoding - 321 BUKIT BATOK ST 33
# Geocoding - 409 BUKIT BATOK WEST AVE 4
# Geocoding - 161 BUKIT BATOK ST 11
# Geocoding - 265 BUKIT BATOK EAST AVE 4
# Geocoding - 225 BUKIT BATOK CENTRAL
# Geocoding - 235 BUKIT BATOK EAST AVE 5
# Geocoding - 363 BUKIT BATOK ST 31
# Geocoding - 178 BUKIT BATOK WEST AVE 8
# Geocoding - 225 BUKIT BATOK CENTRAL
# Geocoding - 233 BUKIT BATOK EAST AVE 5
# Geocoding - 164 BUKIT BATOK ST 11
# Geocoding - 231 BUKIT BATOK EAST AVE 5
# Geocoding - 238 BUKIT BATOK EAST AVE 5
# Geocoding - 258 BUKIT BATOK EAST AVE 4
# Geocoding - 206 BUKIT BATOK ST 21
# Geocoding - 207 BUKIT BATOK ST 21
# Geocoding - 311 BUKIT BATOK ST 32
# Geocoding - 409 BUKIT BATOK WEST AVE 4
# Geocoding - 510 BUKIT BATOK ST 52
# Geocoding - 417 BUKIT BATOK WEST AVE 4
# Geocoding - 333 BUKIT BATOK ST 32
# Geocoding - 146 BUKIT BATOK WEST AVE 6
# Geocoding - 148 BUKIT BATOK WEST AVE 6
# Geocoding - 105 BUKIT BATOK CENTRAL
# Geocoding - 302 BUKIT BATOK ST 31
# Geocoding - 337 BUKIT BATOK ST 34
# Geocoding - 313 BUKIT BATOK ST 32
# Geocoding - 288D BUKIT BATOK ST 25
# Geocoding - 266 BUKIT BATOK EAST AVE 4
# Geocoding - 266 BUKIT BATOK EAST AVE 4
# Geocoding - 258 BUKIT BATOK EAST AVE 4
# Geocoding - 346 BUKIT BATOK ST 34
# Geocoding - 392 BUKIT BATOK WEST AVE 5
# Geocoding - 291A BUKIT BATOK ST 24
# Geocoding - 185 BUKIT BATOK WEST AVE 6
# Geocoding - 367 BUKIT BATOK ST 31
# Geocoding - 393 BUKIT BATOK WEST AVE 5
# Geocoding - 108 BUKIT BATOK WEST AVE 6
# Geocoding - 391 BUKIT BATOK WEST AVE 5
# Geocoding - 290E BUKIT BATOK ST 24
# Geocoding - 383 BUKIT BATOK WEST AVE 5
# Geocoding - 201 BUKIT BATOK ST 21
# Geocoding - 290F BUKIT BATOK ST 24
# Geocoding - 291E BUKIT BATOK ST 24
# Geocoding - 419 BUKIT BATOK WEST AVE 2
# Geocoding - 191 BUKIT BATOK WEST AVE 6
# Geocoding - 189 BUKIT BATOK WEST AVE 6
# Geocoding - 390 BUKIT BATOK WEST AVE 5
# Geocoding - 297 BUKIT BATOK ST 22
# Geocoding - 286 BUKIT BATOK EAST AVE 3
# Geocoding - 110 BUKIT BATOK WEST AVE 6
# Geocoding - 288E BUKIT BATOK ST 25
# Geocoding - 297 BUKIT BATOK ST 22
# Geocoding - 402 BUKIT BATOK WEST AVE 7
# Geocoding - 406 BUKIT BATOK WEST AVE 7
# Geocoding - 526 BUKIT BATOK ST 51
# Geocoding - 141 BUKIT BATOK ST 11
# Geocoding - 140 BUKIT BATOK ST 11
# Geocoding - 288A BUKIT BATOK ST 25
# Geocoding - 138 JALAN BUKIT MERAH
# Geocoding - 116 BUKIT MERAH VIEW
# Geocoding - 129 BUKIT MERAH VIEW
# Geocoding - 46 JALAN BUKIT HO SWEE
# Geocoding - 130 BUKIT MERAH VIEW
# Geocoding - 109 BUKIT PURMEI RD
# Geocoding - 128 BUKIT MERAH VIEW
# Geocoding - 26D JALAN MEMBINA
# Geocoding - 108 JALAN BUKIT MERAH
# Geocoding - 111 BUKIT PURMEI RD
# Geocoding - 40 JALAN RUMAH TINGGI
# Geocoding - 8 JALAN RUMAH TINGGI
# Geocoding - 40 JALAN RUMAH TINGGI
# Geocoding - 12 JALAN BUKIT MERAH
# Geocoding - 27A JALAN MEMBINA
# Geocoding - 117 BUKIT MERAH CENTRAL
# Geocoding - 9 JALAN RUMAH TINGGI
# Geocoding - 118B JALAN MEMBINA
# Geocoding - 611 BUKIT PANJANG RING RD
# Geocoding - 537 BUKIT PANJANG RING RD
# Geocoding - 10 JALAN KUKOH
# Geocoding - 34 UPPER CROSS ST
# Geocoding - 532 UPPER CROSS ST
# Geocoding - 2 TG PAGAR PLAZA
# Geocoding - 533 UPPER CROSS ST
# Geocoding - 3 TG PAGAR PLAZA
# Geocoding - 219 CHOA CHU KANG CENTRAL
# Geocoding - 217 CHOA CHU KANG CENTRAL
# Geocoding - 224 CHOA CHU KANG CENTRAL
# Geocoding - 154 JALAN TECK WHYE
# Geocoding - 752 CHOA CHU KANG NORTH 5
# Geocoding - 632 CHOA CHU KANG NORTH 6
# Geocoding - 792 CHOA CHU KANG NORTH 6
# Geocoding - 618 CHOA CHU KANG NORTH 7
# Geocoding - 163 JALAN TECK WHYE
# Geocoding - 164 JALAN TECK WHYE
# Geocoding - 207 CHOA CHU KANG CENTRAL
# Geocoding - 411 COMMONWEALTH AVE WEST
# Geocoding - 414 COMMONWEALTH AVE WEST
# Geocoding - 39 JALAN TIGA
# Geocoding - 45 JALAN TIGA
# Geocoding - 138 LORONG AH SOO
# Geocoding - 143 LORONG AH SOO
# Geocoding - 134 LORONG AH SOO
# Geocoding - 142 LORONG AH SOO
# Geocoding - 835 HOUGANG CENTRAL
# Geocoding - 141 LORONG AH SOO
# Geocoding - 682C JURONG WEST CENTRAL 1
# Geocoding - 686C JURONG WEST CENTRAL 1
# Geocoding - 683B JURONG WEST CENTRAL 1
# Geocoding - 686C JURONG WEST CENTRAL 1
# Geocoding - 682A JURONG WEST CENTRAL 1
# Geocoding - 683B JURONG WEST CENTRAL 1
# Geocoding - 692 JURONG WEST CENTRAL 1
# Geocoding - 33 JALAN BAHAGIA
# Geocoding - 76 LORONG LIMAU
# Geocoding - 76 LORONG LIMAU
# Geocoding - 468 NORTH BRIDGE RD
# Geocoding - 468 NORTH BRIDGE RD
# Geocoding - 53 JALAN MA'MOR
# Geocoding - 14 UPPER BOON KENG RD
# Geocoding - 2B UPPER BOON KENG RD
# Geocoding - 16 JALAN TENTERAM
# Geocoding - 18 JALAN TENTERAM
# Geocoding - 3C UPPER BOON KENG RD
# Geocoding - 601A PUNGGOL CENTRAL
# Geocoding - 601A PUNGGOL CENTRAL
# Geocoding - 601D PUNGGOL CENTRAL
# Geocoding - 296 PUNGGOL CENTRAL
# Geocoding - 601D PUNGGOL CENTRAL
# Geocoding - 646 PUNGGOL CENTRAL
# Geocoding - 648 PUNGGOL CENTRAL
# Geocoding - 601A PUNGGOL CENTRAL
# Geocoding - 602A PUNGGOL CENTRAL
# Geocoding - 601D PUNGGOL CENTRAL
# Geocoding - 301A PUNGGOL CENTRAL
# Geocoding - 303C PUNGGOL CENTRAL
# Geocoding - 303A PUNGGOL CENTRAL
# Geocoding - 301B PUNGGOL CENTRAL
# Geocoding - 301A PUNGGOL CENTRAL
# Geocoding - 643 PUNGGOL CENTRAL
# Geocoding - 160A PUNGGOL CENTRAL
# Geocoding - 166A PUNGGOL CENTRAL
# Geocoding - 648 PUNGGOL CENTRAL
# Geocoding - 649 PUNGGOL CENTRAL
# Geocoding - 86 COMMONWEALTH CL
# Geocoding - 97 COMMONWEALTH CRES
# Geocoding - 110 COMMONWEALTH CRES
# Geocoding - 111 COMMONWEALTH CRES
# Geocoding - 82 COMMONWEALTH CL
# Geocoding - 94 COMMONWEALTH DR
# Geocoding - 83 COMMONWEALTH CL
# Geocoding - 85 COMMONWEALTH CL
# Geocoding - 94 COMMONWEALTH DR
# Geocoding - 88 COMMONWEALTH CL
# Geocoding - 98 COMMONWEALTH CRES
# Geocoding - 466C SEMBAWANG DR
# Geocoding - 447A JALAN KAYU
# Geocoding - 272D SENGKANG CENTRAL
# Geocoding - 271A SENGKANG CENTRAL
# Geocoding - 271C SENGKANG CENTRAL
# Geocoding - 272D SENGKANG CENTRAL
# Geocoding - 152 SERANGOON NORTH AVE 1
# Geocoding - 147 SERANGOON NORTH AVE 1
# Geocoding - 3 LORONG LEW LIAN
# Geocoding - 261 SERANGOON CENTRAL DR
# Geocoding - 1 LORONG LEW LIAN
# Geocoding - 206 SERANGOON CENTRAL
# Geocoding - 147 SERANGOON NORTH AVE 1
# Geocoding - 127 SERANGOON NORTH AVE 1
# Geocoding - 101 SERANGOON NORTH AVE 1
# Geocoding - 510 SERANGOON NORTH AVE 4
# Geocoding - 553 SERANGOON NORTH AVE 3
# Geocoding - 507 SERANGOON NORTH AVE 4
# Geocoding - 118 SERANGOON NORTH AVE 1
# Geocoding - 144 SERANGOON NORTH AVE 1
# Geocoding - 551 SERANGOON NORTH AVE 3
# Geocoding - 210 SERANGOON CENTRAL
# Geocoding - 419 SERANGOON CENTRAL
# Geocoding - 528 SERANGOON NORTH AVE 4
# Geocoding - 548 SERANGOON NORTH AVE 3
# Geocoding - 507 SERANGOON NORTH AVE 4
# Geocoding - 540 SERANGOON NORTH AVE 4
# Geocoding - 552 SERANGOON NORTH AVE 3
# Geocoding - 257 SERANGOON CENTRAL DR
# Geocoding - 123 SERANGOON NORTH AVE 1
# Geocoding - 506B SERANGOON NORTH AVE 4
# Geocoding - 535 SERANGOON NORTH AVE 4
# Geocoding - 142 SERANGOON NORTH AVE 1
# Geocoding - 125 SERANGOON NORTH AVE 1
# Geocoding - 515B TAMPINES CENTRAL 7
# Geocoding - 515B TAMPINES CENTRAL 7
# Geocoding - 518B TAMPINES CENTRAL 7
# Geocoding - 518A TAMPINES CENTRAL 7
# Geocoding - 52 LORONG 6 TOA PAYOH
# Geocoding - 52 LORONG 6 TOA PAYOH
# Geocoding - 51 LORONG 6 TOA PAYOH
# Geocoding - 3 UPPER ALJUNIED LANE
# Geocoding - 225 LORONG 8 TOA PAYOH
# Geocoding - 5 UPPER ALJUNIED LANE
# Geocoding - 66 LORONG 4 TOA PAYOH
# Geocoding - 73 LORONG 4 TOA PAYOH
# Geocoding - 3 LORONG 7 TOA PAYOH
# Geocoding - 113 LORONG 1 TOA PAYOH
# Geocoding - 128 LORONG 1 TOA PAYOH
# Geocoding - 116 LORONG 2 TOA PAYOH
# Geocoding - 115 LORONG 1 TOA PAYOH
# Geocoding - 117 LORONG 1 TOA PAYOH
# Geocoding - 73 LORONG 4 TOA PAYOH
# Geocoding - 207 TOA PAYOH NORTH
# Geocoding - 73 LORONG 4 TOA PAYOH
# Geocoding - 109 LORONG 1 TOA PAYOH
# Geocoding - 158 LORONG 1 TOA PAYOH
# Geocoding - 220 LORONG 8 TOA PAYOH
# Geocoding - 213 LORONG 8 TOA PAYOH
# Geocoding - 204 TOA PAYOH NORTH
# Geocoding - 208 TOA PAYOH NORTH
# Geocoding - 172A LORONG 1 TOA PAYOH
# Geocoding - 79B TOA PAYOH CENTRAL
# Geocoding - 143 LORONG 2 TOA PAYOH
# Geocoding - 14A LORONG 7 TOA PAYOH
# Geocoding - 171 LORONG 1 TOA PAYOH
# Geocoding - 37 LORONG 5 TOA PAYOH
# Geocoding - 121 LORONG 2 TOA PAYOH
# Geocoding - 79E TOA PAYOH CENTRAL
# Geocoding - 122 LORONG 2 TOA PAYOH
# Geocoding - 141 LORONG 2 TOA PAYOH
# Geocoding - 79D TOA PAYOH CENTRAL
# Geocoding - 146 LORONG 2 TOA PAYOH
# Geocoding - 81B LORONG 4 TOA PAYOH
# Geocoding - 79E TOA PAYOH CENTRAL
# Geocoding - 79B TOA PAYOH CENTRAL
# Geocoding - 141 LORONG 2 TOA PAYOH
# Geocoding - 145 LORONG 2 TOA PAYOH
# Geocoding - 79B TOA PAYOH CENTRAL
# Geocoding - 11 LORONG 8 TOA PAYOH
# Geocoding - 60 LORONG 4 TOA PAYOH
# Geocoding - 154 LORONG 2 TOA PAYOH
# Geocoding - 153A LORONG 1 TOA PAYOH
# Geocoding - 145 LORONG 2 TOA PAYOH
# Geocoding - 237 LORONG 1 TOA PAYOH
# Geocoding - 303 YISHUN CENTRAL
# Geocoding - 322 YISHUN CENTRAL
# Geocoding - 305 YISHUN CENTRAL
# Geocoding - 106 BEDOK NORTH AVE 4
# Geocoding - 535 BEDOK NORTH ST 3
# Geocoding - 502 BEDOK NORTH ST 3
# Geocoding - 77 BEDOK NORTH RD
# Geocoding - 510 BEDOK NORTH ST 3
# Geocoding - 504 BEDOK NORTH ST 3
# Geocoding - 549 BEDOK NORTH AVE 1
# Geocoding - 501 BEDOK NORTH ST 3
# Geocoding - 529 BEDOK NORTH ST 3
# Geocoding - 503 BEDOK NORTH ST 3
# Geocoding - 100 BEDOK NORTH AVE 4
# Geocoding - 510 BEDOK NORTH ST 3
# Geocoding - 510 BEDOK NORTH ST 3
# Geocoding - 530 BEDOK NORTH ST 3
# Geocoding - 521 BEDOK NORTH AVE 1
# Geocoding - 401 BEDOK NORTH AVE 3
# Geocoding - 510 BEDOK NORTH ST 3
# Geocoding - 123 BEDOK NORTH ST 2
# Geocoding - 107 BEDOK NORTH RD
# Geocoding - 536 BEDOK NORTH ST 3
# Geocoding - 549 BEDOK NORTH AVE 1
# Geocoding - 520 BEDOK NORTH AVE 1
# Geocoding - 30 NEW UPPER CHANGI RD
# Geocoding - 515 BEDOK NORTH AVE 2
# Geocoding - 420 BEDOK NORTH ST 1
# Geocoding - 554 BEDOK NORTH ST 3
# Geocoding - 530 BEDOK NORTH ST 3
# Geocoding - 204 BEDOK NORTH ST 1
# Geocoding - 418 BEDOK NORTH AVE 2
# Geocoding - 423 BEDOK NORTH AVE 1
# Geocoding - 412 BEDOK NORTH AVE 2
# Geocoding - 409 BEDOK NORTH AVE 2
# Geocoding - 409 BEDOK NORTH AVE 2
# Geocoding - 220A BEDOK CENTRAL
# Geocoding - 524 BEDOK NORTH ST 3
# Geocoding - 79 BEDOK NORTH RD
# Geocoding - 546 BEDOK NORTH ST 3
# Geocoding - 82 BEDOK NORTH RD
# Geocoding - 545 BEDOK NORTH ST 3
# Geocoding - 95 BEDOK NORTH AVE 4
# Geocoding - 64 NEW UPPER CHANGI RD
# Geocoding - 428 BEDOK NORTH RD
# Geocoding - 428 BEDOK NORTH RD
# Geocoding - 421 BEDOK NORTH RD
# Geocoding - 65 NEW UPPER CHANGI RD
# Geocoding - 421 BEDOK NORTH RD
# Geocoding - 422 BEDOK NORTH RD
# Geocoding - 181 BEDOK NORTH RD
# Geocoding - 181 BEDOK NORTH RD
# Geocoding - 219B BEDOK CENTRAL
# Geocoding - 111 BEDOK NORTH RD
# Geocoding - 98 BEDOK NORTH AVE 4
# Geocoding - 552 BEDOK NORTH AVE 1
# Geocoding - 341 BUKIT BATOK ST 34
# Geocoding - 259 BUKIT BATOK EAST AVE 4
# Geocoding - 425 BUKIT BATOK WEST AVE 2
# Geocoding - 321 BUKIT BATOK ST 33
# Geocoding - 536 BUKIT BATOK ST 52
# Geocoding - 413 BUKIT BATOK WEST AVE 4
# Geocoding - 267 BUKIT BATOK EAST AVE 4
# Geocoding - 182 BUKIT BATOK WEST AVE 8
# Geocoding - 231 BUKIT BATOK EAST AVE 5
# Geocoding - 359 BUKIT BATOK ST 31
# Geocoding - 316 BUKIT BATOK ST 32
# Geocoding - 180 BUKIT BATOK WEST AVE 8
# Geocoding - 230 BUKIT BATOK EAST AVE 3
# Geocoding - 260 BUKIT BATOK EAST AVE 4
# Geocoding - 345 BUKIT BATOK ST 34
# Geocoding - 226 BUKIT BATOK CENTRAL
# Geocoding - 180 BUKIT BATOK WEST AVE 8
# Geocoding - 321 BUKIT BATOK ST 33
# Geocoding - 501 BUKIT BATOK ST 52
# Geocoding - 129 BUKIT BATOK WEST AVE 6
# Geocoding - 233 BUKIT BATOK EAST AVE 5
# Geocoding - 241 BUKIT BATOK EAST AVE 5
# Geocoding - 145 BUKIT BATOK ST 11
# Geocoding - 411 BUKIT BATOK WEST AVE 4
# Geocoding - 109 BUKIT BATOK WEST AVE 6
# Geocoding - 227 BUKIT BATOK CENTRAL
# Geocoding - 231 BUKIT BATOK EAST AVE 5
# Geocoding - 367 BUKIT BATOK ST 31
# Geocoding - 175 BUKIT BATOK WEST AVE 8
# Geocoding - 136 BUKIT BATOK WEST AVE 6
# Geocoding - 514 BUKIT BATOK ST 52
# Geocoding - 365 BUKIT BATOK ST 31
# Geocoding - 315 BUKIT BATOK ST 32
# Geocoding - 308 BUKIT BATOK ST 31
# Geocoding - 358 BUKIT BATOK ST 31
# Geocoding - 301 BUKIT BATOK ST 31
# Geocoding - 309 BUKIT BATOK ST 31
# Geocoding - 308 BUKIT BATOK ST 31
# Geocoding - 186 BUKIT BATOK WEST AVE 6
# Geocoding - 291B BUKIT BATOK ST 24
# Geocoding - 229 BUKIT BATOK EAST AVE 3
# Geocoding - 511 BUKIT BATOK ST 52
# Geocoding - 321 BUKIT BATOK ST 33
# Geocoding - 411 BUKIT BATOK WEST AVE 4
# Geocoding - 289F BUKIT BATOK ST 25
# Geocoding - 113 BUKIT BATOK WEST AVE 6
# Geocoding - 291E BUKIT BATOK ST 24
# Geocoding - 288D BUKIT BATOK ST 25
# Geocoding - 225 BUKIT BATOK CENTRAL
# Geocoding - 290F BUKIT BATOK ST 24
# Geocoding - 187 BUKIT BATOK WEST AVE 6
# Geocoding - 231 BUKIT BATOK EAST AVE 5
# Geocoding - 385 BUKIT BATOK WEST AVE 5
# Geocoding - 101 BUKIT BATOK WEST AVE 6
# Geocoding - 211 BUKIT BATOK ST 21
# Geocoding - 384 BUKIT BATOK WEST AVE 5
# Geocoding - 383 BUKIT BATOK WEST AVE 5
# Geocoding - 626 BUKIT BATOK CENTRAL
# Geocoding - 301 BUKIT BATOK ST 31
# Geocoding - 388 BUKIT BATOK WEST AVE 5
# Geocoding - 291C BUKIT BATOK ST 24
# Geocoding - 388 BUKIT BATOK WEST AVE 5
# Geocoding - 387 BUKIT BATOK WEST AVE 5
# Geocoding - 203 BUKIT BATOK ST 21
# Geocoding - 203 BUKIT BATOK ST 21
# Geocoding - 406 BUKIT BATOK WEST AVE 7
# Geocoding - 140 BUKIT BATOK ST 11
# Geocoding - 142 BUKIT BATOK ST 11
# Geocoding - 627 BUKIT BATOK CENTRAL
# Geocoding - 2 JALAN BUKIT HO SWEE
# Geocoding - 37 JALAN RUMAH TINGGI
# Geocoding - 137 JALAN BUKIT MERAH
# Geocoding - 138 JALAN BUKIT MERAH
# Geocoding - 101 BUKIT PURMEI RD
# Geocoding - 2 JALAN BUKIT MERAH
# Geocoding - 119 BUKIT MERAH VIEW
# Geocoding - 34 JALAN BUKIT HO SWEE
# Geocoding - 130 BUKIT MERAH VIEW
# Geocoding - 145 JALAN BUKIT MERAH
# Geocoding - 120 BUKIT MERAH VIEW
# Geocoding - 22 JALAN MEMBINA
# Geocoding - 113 BUKIT PURMEI RD
# Geocoding - 40 JALAN RUMAH TINGGI
# Geocoding - 26C JALAN MEMBINA
# Geocoding - 115 BUKIT MERAH CENTRAL
# Geocoding - 240 BUKIT PANJANG RING RD
# Geocoding - 236 BUKIT PANJANG RING RD
# Geocoding - 611 BUKIT PANJANG RING RD
# Geocoding - 429 BUKIT PANJANG RING RD
# Geocoding - 239 BUKIT PANJANG RING RD
# Geocoding - 5 TG PAGAR PLAZA
# Geocoding - 536 UPPER CROSS ST
# Geocoding - 5 TG PAGAR PLAZA
# Geocoding - 1 TG PAGAR PLAZA
# Geocoding - 536 UPPER CROSS ST
# Geocoding - 152 JALAN TECK WHYE
# Geocoding - 157 JALAN TECK WHYE
# Geocoding - 160 JALAN TECK WHYE
# Geocoding - 230 CHOA CHU KANG CENTRAL
# Geocoding - 238 CHOA CHU KANG CENTRAL
# Geocoding - 225 CHOA CHU KANG CENTRAL
# Geocoding - 220 CHOA CHU KANG CENTRAL
# Geocoding - 755 CHOA CHU KANG NORTH 5
# Geocoding - 410 COMMONWEALTH AVE WEST
# Geocoding - 412 COMMONWEALTH AVE WEST
# Geocoding - 414 COMMONWEALTH AVE WEST
# Geocoding - 415 COMMONWEALTH AVE WEST
# Geocoding - 139 LORONG AH SOO
# Geocoding - 139 LORONG AH SOO
# Geocoding - 464 UPPER SERANGOON RD
# Geocoding - 837 HOUGANG CENTRAL
# Geocoding - 128 LORONG AH SOO
# Geocoding - 686A JURONG WEST CENTRAL 1
# Geocoding - 161 YUNG PING RD
# Geocoding - 34 JALAN BAHAGIA
# Geocoding - 3A UPPER BOON KENG RD
# Geocoding - 3D UPPER BOON KENG RD
# Geocoding - 39 UPPER BOON KENG RD
# Geocoding - 102 JALAN DUSUN
# Geocoding - 17 JALAN TENTERAM
# Geocoding - 2B UPPER BOON KENG RD
# Geocoding - 103 JALAN RAJAH
# Geocoding - 3A UPPER BOON KENG RD
# Geocoding - 14A UPPER BOON KENG RD
# Geocoding - 601B PUNGGOL CENTRAL
# Geocoding - 297 PUNGGOL CENTRAL
# Geocoding - 301A PUNGGOL CENTRAL
# Geocoding - 645 PUNGGOL CENTRAL
# Geocoding - 647 PUNGGOL CENTRAL
# Geocoding - 293 PUNGGOL CENTRAL
# Geocoding - 186 PUNGGOL CENTRAL
# Geocoding - 188 PUNGGOL CENTRAL
# Geocoding - 192 PUNGGOL CENTRAL
# Geocoding - 89 COMMONWEALTH DR
# Geocoding - 109 COMMONWEALTH CRES
# Geocoding - 7A COMMONWEALTH AVE
# Geocoding - 272B SENGKANG CENTRAL
# Geocoding - 272A SENGKANG CENTRAL
# Geocoding - 272C SENGKANG CENTRAL
# Geocoding - 272D SENGKANG CENTRAL
# Geocoding - 272C SENGKANG CENTRAL
# Geocoding - 105 SERANGOON NORTH AVE 1
# Geocoding - 147 SERANGOON NORTH AVE 1
# Geocoding - 5 LORONG LEW LIAN
# Geocoding - 107 SERANGOON NORTH AVE 1
# Geocoding - 153 SERANGOON NORTH AVE 1
# Geocoding - 4 LORONG LEW LIAN
# Geocoding - 201 SERANGOON CENTRAL
# Geocoding - 254 SERANGOON CENTRAL DR
# Geocoding - 103 SERANGOON NORTH AVE 1
# Geocoding - 126 SERANGOON NORTH AVE 1
# Geocoding - 154 SERANGOON NORTH AVE 1
# Geocoding - 548 SERANGOON NORTH AVE 3
# Geocoding - 508 SERANGOON NORTH AVE 4
# Geocoding - 507 SERANGOON NORTH AVE 4
# Geocoding - 117 SERANGOON NORTH AVE 1
# Geocoding - 529 SERANGOON NORTH AVE 4
# Geocoding - 143 SERANGOON NORTH AVE 1
# Geocoding - 504 SERANGOON NORTH AVE 4
# Geocoding - 500 SERANGOON NORTH AVE 4
# Geocoding - 533 SERANGOON NORTH AVE 4
# Geocoding - 258 SERANGOON CENTRAL DR
# Geocoding - 537 SERANGOON NORTH AVE 4
# Geocoding - 544 SERANGOON NORTH AVE 3
# Geocoding - 516 SERANGOON NORTH AVE 4
# Geocoding - 515C TAMPINES CENTRAL 7
# Geocoding - 518D TAMPINES CENTRAL 7
# Geocoding - 515C TAMPINES CENTRAL 7
# Geocoding - 52 LORONG 6 TOA PAYOH
# Geocoding - 71 LORONG 4 TOA PAYOH
# Geocoding - 3 LORONG 7 TOA PAYOH
# Geocoding - 92 LORONG 4 TOA PAYOH
# Geocoding - 8 LORONG 7 TOA PAYOH
# Geocoding - 12 LORONG 7 TOA PAYOH
# Geocoding - 18 LORONG 7 TOA PAYOH
# Geocoding - 116 LORONG 2 TOA PAYOH
# Geocoding - 3 LORONG 7 TOA PAYOH
# Geocoding - 113 LORONG 1 TOA PAYOH
# Geocoding - 98 LORONG 1 TOA PAYOH
# Geocoding - 183 TOA PAYOH CENTRAL
# Geocoding - 205 TOA PAYOH NORTH
# Geocoding - 85A LORONG 4 TOA PAYOH
# Geocoding - 85A LORONG 4 TOA PAYOH
# Geocoding - 201 TOA PAYOH NORTH
# Geocoding - 222 LORONG 8 TOA PAYOH
# Geocoding - 222 LORONG 8 TOA PAYOH
# Geocoding - 228 LORONG 8 TOA PAYOH
# Geocoding - 10B LORONG 7 TOA PAYOH
# Geocoding - 122 LORONG 2 TOA PAYOH
# Geocoding - 146 LORONG 2 TOA PAYOH
# Geocoding - 147 LORONG 2 TOA PAYOH
# Geocoding - 146 LORONG 2 TOA PAYOH
# Geocoding - 236 LORONG 1 TOA PAYOH
# Geocoding - 101A LORONG 2 TOA PAYOH
# Geocoding - 306 YISHUN CENTRAL
# Geocoding - 325 YISHUN CENTRAL
# Geocoding - 75 BEDOK NORTH RD
# Geocoding - 503 BEDOK NORTH ST 3
# Geocoding - 502 BEDOK NORTH ST 3
# Geocoding - 539 BEDOK NORTH ST 3
# Geocoding - 519 BEDOK NORTH AVE 1
# Geocoding - 115 BEDOK NORTH RD
# Geocoding - 124 BEDOK NORTH RD
# Geocoding - 535 BEDOK NORTH ST 3
# Geocoding - 522 BEDOK NORTH AVE 1
# Geocoding - 522 BEDOK NORTH AVE 1
# Geocoding - 125 BEDOK NORTH RD
# Geocoding - 539 BEDOK NORTH ST 3
# Geocoding - 533 BEDOK NORTH ST 3
# Geocoding - 539 BEDOK NORTH ST 3
# Geocoding - 542 BEDOK NORTH ST 3
# Geocoding - 525 BEDOK NORTH ST 3
# Geocoding - 534 BEDOK NORTH ST 3
# Geocoding - 540 BEDOK NORTH ST 3
# Geocoding - 27 NEW UPPER CHANGI RD
# Geocoding - 522 BEDOK NORTH AVE 1
# Geocoding - 550 BEDOK NORTH AVE 1
# Geocoding - 103 BEDOK NORTH AVE 4
# Geocoding - 28 NEW UPPER CHANGI RD
# Geocoding - 28 NEW UPPER CHANGI RD
# Geocoding - 107 BEDOK NORTH RD
# Geocoding - 128 BEDOK NORTH ST 2
# Geocoding - 77 BEDOK NORTH RD
# Geocoding - 539 BEDOK NORTH ST 3
# Geocoding - 124 BEDOK NORTH RD
# Geocoding - 24 NEW UPPER CHANGI RD
# Geocoding - 201 BEDOK NORTH ST 1
# Geocoding - 122 BEDOK NORTH ST 2
# Geocoding - 202 BEDOK NORTH ST 1
# Geocoding - 524 BEDOK NORTH ST 3
# Geocoding - 554 BEDOK NORTH ST 3
# Geocoding - 547 BEDOK NORTH ST 3
# Geocoding - 547 BEDOK NORTH ST 3
# Geocoding - 93 BEDOK NORTH AVE 4
# Geocoding - 119 BEDOK NORTH RD
# Geocoding - 547 BEDOK NORTH ST 3
# Geocoding - 403 BEDOK NORTH AVE 3
# Geocoding - 513 BEDOK NORTH AVE 2
# Geocoding - 521 BEDOK NORTH AVE 1
# Geocoding - 404 BEDOK NORTH AVE 3
# Geocoding - 523 BEDOK NORTH ST 3
# Geocoding - 115 BEDOK NORTH RD
# Geocoding - 532 BEDOK NORTH ST 3
# Geocoding - 507 BEDOK NORTH AVE 3
# Geocoding - 517 BEDOK NORTH AVE 2
# Geocoding - 428 BEDOK NORTH RD
# Geocoding - 65 NEW UPPER CHANGI RD
# Geocoding - 425 BEDOK NORTH RD
# Geocoding - 132 BEDOK NORTH ST 2
# Geocoding - 181 BEDOK NORTH RD
# Geocoding - 182 BEDOK NORTH RD
# Geocoding - 219D BEDOK CENTRAL
# Geocoding - 221B BEDOK CENTRAL
# Geocoding - 220B BEDOK CENTRAL
# Geocoding - 94E BEDOK NORTH AVE 4
# Geocoding - 96 BEDOK NORTH AVE 4
# Geocoding - 413 BEDOK NORTH AVE 2
# Geocoding - 241 BUKIT BATOK EAST AVE 5
# Geocoding - 345 BUKIT BATOK ST 34
# Geocoding - 506 BUKIT BATOK ST 52
# Geocoding - 251 BUKIT BATOK EAST AVE 5
# Geocoding - 249 BUKIT BATOK EAST AVE 5
# Geocoding - 248 BUKIT BATOK EAST AVE 5
# Geocoding - 534 BUKIT BATOK ST 51
# Geocoding - 407 BUKIT BATOK WEST AVE 4
# Geocoding - 506 BUKIT BATOK ST 52
# Geocoding - 417 BUKIT BATOK WEST AVE 4
# Geocoding - 135 BUKIT BATOK WEST AVE 6
# Geocoding - 239 BUKIT BATOK EAST AVE 5
# Geocoding - 306 BUKIT BATOK ST 31
# Geocoding - 312 BUKIT BATOK ST 32
# Geocoding - 157 BUKIT BATOK ST 11
# Geocoding - 244 BUKIT BATOK EAST AVE 5
# Geocoding - 134 BUKIT BATOK WEST AVE 6
# Geocoding - 316 BUKIT BATOK ST 32
# Geocoding - 235 BUKIT BATOK EAST AVE 5
# Geocoding - 267 BUKIT BATOK EAST AVE 4
# Geocoding - 239 BUKIT BATOK EAST AVE 5
# Geocoding - 239 BUKIT BATOK EAST AVE 5
# Geocoding - 213 BUKIT BATOK ST 21
# Geocoding - 225 BUKIT BATOK CENTRAL
# Geocoding - 164 BUKIT BATOK ST 11
# Geocoding - 167 BUKIT BATOK WEST AVE 8
# Geocoding - 238 BUKIT BATOK EAST AVE 5
# Geocoding - 130 BUKIT BATOK WEST AVE 6
# Geocoding - 507 BUKIT BATOK ST 52
# Geocoding - 505 BUKIT BATOK ST 52
# Geocoding - 239 BUKIT BATOK EAST AVE 5
# Geocoding - 339 BUKIT BATOK ST 34
# Geocoding - 148 BUKIT BATOK WEST AVE 6
# Geocoding - 138 BUKIT BATOK WEST AVE 6
# Geocoding - 348 BUKIT BATOK ST 34
# Geocoding - 305 BUKIT BATOK ST 31
# Geocoding - 315 BUKIT BATOK ST 32
# Geocoding - 363 BUKIT BATOK ST 31
# Geocoding - 346 BUKIT BATOK ST 34
# Geocoding - 289F BUKIT BATOK ST 25
# Geocoding - 411 BUKIT BATOK WEST AVE 4
# Geocoding - 414 BUKIT BATOK WEST AVE 4
# Geocoding - 360 BUKIT BATOK ST 31
# Geocoding - 343 BUKIT BATOK ST 34
# Geocoding - 363 BUKIT BATOK ST 31
# Geocoding - 165 BUKIT BATOK WEST AVE 8
# Geocoding - 313 BUKIT BATOK ST 32
# Geocoding - 383 BUKIT BATOK WEST AVE 5
# Geocoding - 162 BUKIT BATOK ST 11
# Geocoding - 219 BUKIT BATOK ST 21
# Geocoding - 304 BUKIT BATOK ST 31
# Geocoding - 190 BUKIT BATOK WEST AVE 6
# Geocoding - 395 BUKIT BATOK WEST AVE 5
# Geocoding - 187 BUKIT BATOK WEST AVE 6
# Geocoding - 187 BUKIT BATOK WEST AVE 6
# Geocoding - 211 BUKIT BATOK ST 21
# Geocoding - 386 BUKIT BATOK WEST AVE 5
# Geocoding - 203 BUKIT BATOK ST 21
# Geocoding - 104 BUKIT BATOK CENTRAL
# Geocoding - 626 BUKIT BATOK CENTRAL
# Geocoding - 203 BUKIT BATOK ST 21
# Geocoding - 426 BUKIT BATOK WEST AVE 2
# Geocoding - 288B BUKIT BATOK ST 25
# Geocoding - 384 BUKIT BATOK WEST AVE 5
# Geocoding - 189 BUKIT BATOK WEST AVE 6
# Geocoding - 170 BUKIT BATOK WEST AVE 8
# Geocoding - 622 BUKIT BATOK CENTRAL
# Geocoding - 354 BUKIT BATOK ST 31
# Geocoding - 524 BUKIT BATOK ST 52
# Geocoding - 299 BUKIT BATOK ST 22
# Geocoding - 288G BUKIT BATOK ST 25
# Geocoding - 116 BUKIT MERAH VIEW
# Geocoding - 131 JALAN BUKIT MERAH
# Geocoding - 142 JALAN BUKIT MERAH
# Geocoding - 146 JALAN BUKIT MERAH
# Geocoding - 119 BUKIT MERAH VIEW
# Geocoding - 119 BUKIT MERAH VIEW
# Geocoding - 119 BUKIT MERAH VIEW
# Geocoding - 104 BUKIT PURMEI RD
# Geocoding - 108 JALAN BUKIT MERAH
# Geocoding - 112 BUKIT PURMEI RD
# Geocoding - 118D JALAN MEMBINA
# Geocoding - 38 JALAN RUMAH TINGGI
# Geocoding - 118D JALAN MEMBINA
# Geocoding - 27A JALAN MEMBINA
# Geocoding - 124A BUKIT MERAH VIEW
# Geocoding - 26D JALAN MEMBINA
# Geocoding - 35 JALAN RUMAH TINGGI
# Geocoding - 9 JALAN RUMAH TINGGI
# Geocoding - 8 JALAN RUMAH TINGGI
# Geocoding - 115 BUKIT PURMEI RD
# Geocoding - 447 BUKIT PANJANG RING RD
# Geocoding - 609 BUKIT PANJANG RING RD
# Geocoding - 609 BUKIT PANJANG RING RD
# Geocoding - 244 BUKIT PANJANG RING RD
# Geocoding - 609 BUKIT PANJANG RING RD
# Geocoding - 617 BUKIT PANJANG RING RD
# Geocoding - 617 BUKIT PANJANG RING RD
# Geocoding - 239 BUKIT PANJANG RING RD
# Geocoding - 34 UPPER CROSS ST
# Geocoding - 536 UPPER CROSS ST
# Geocoding - 533 UPPER CROSS ST
# Geocoding - 533 UPPER CROSS ST
# Geocoding - 8 TG PAGAR PLAZA
# Geocoding - 152 JALAN TECK WHYE
# Geocoding - 234 CHOA CHU KANG CENTRAL
# Geocoding - 227 CHOA CHU KANG CENTRAL
# Geocoding - 213 CHOA CHU KANG CENTRAL
# Geocoding - 157 JALAN TECK WHYE
# Geocoding - 158 JALAN TECK WHYE
# Geocoding - 212 CHOA CHU KANG CENTRAL
# Geocoding - 790 CHOA CHU KANG NORTH 6
# Geocoding - 636 CHOA CHU KANG NORTH 6
# Geocoding - 765 CHOA CHU KANG NORTH 5
# Geocoding - 162 JALAN TECK WHYE
# Geocoding - 561 CHOA CHU KANG NORTH 6
# Geocoding - 555 CHOA CHU KANG NORTH 6
# Geocoding - 415 COMMONWEALTH AVE WEST
# Geocoding - 49 JALAN TIGA
# Geocoding - 123 GEYLANG EAST CENTRAL
# Geocoding - 134 LORONG AH SOO
# Geocoding - 830 HOUGANG CENTRAL
# Geocoding - 144 LORONG AH SOO
# Geocoding - 145 LORONG AH SOO
# Geocoding - 850 HOUGANG CENTRAL
# Geocoding - 834 HOUGANG CENTRAL
# Geocoding - 682C JURONG WEST CENTRAL 1
# Geocoding - 693 JURONG WEST CENTRAL 1
# Geocoding - 694 JURONG WEST CENTRAL 1
# Geocoding - 682A JURONG WEST CENTRAL 1
# Geocoding - 160 YUNG PING RD
# Geocoding - 682A JURONG WEST CENTRAL 1
# Geocoding - 28 JALAN BAHAGIA
# Geocoding - 27 JALAN BAHAGIA
# Geocoding - 32 JALAN BAHAGIA
# Geocoding - 35 JALAN BAHAGIA
# Geocoding - 76 LORONG LIMAU
# Geocoding - 12 UPPER BOON KENG RD
# Geocoding - 468 NORTH BRIDGE RD
# Geocoding - 11 UPPER BOON KENG RD
# Geocoding - 59 JALAN MA'MOR
# Geocoding - 30 JALAN BAHAGIA
# Geocoding - 18 JALAN TENTERAM
# Geocoding - 16 JALAN TENTERAM
# Geocoding - 14A UPPER BOON KENG RD
# Geocoding - 39 UPPER BOON KENG RD
# Geocoding - 16 JALAN TENTERAM
# Geocoding - 11 UPPER BOON KENG RD
# Geocoding - 3D UPPER BOON KENG RD
# Geocoding - 601D PUNGGOL CENTRAL
# Geocoding - 601D PUNGGOL CENTRAL
# Geocoding - 602A PUNGGOL CENTRAL
# Geocoding - 601A PUNGGOL CENTRAL
# Geocoding - 165A PUNGGOL CENTRAL
# Geocoding - 649 PUNGGOL CENTRAL
# Geocoding - 294 PUNGGOL CENTRAL
# Geocoding - 647 PUNGGOL CENTRAL
# Geocoding - 602A PUNGGOL CENTRAL
# Geocoding - 601A PUNGGOL CENTRAL
# Geocoding - 303C PUNGGOL CENTRAL
# Geocoding - 301A PUNGGOL CENTRAL
# Geocoding - 301A PUNGGOL CENTRAL
# Geocoding - 190 PUNGGOL CENTRAL
# Geocoding - 165B PUNGGOL CENTRAL
# Geocoding - 648 PUNGGOL CENTRAL
# Geocoding - 651 PUNGGOL CENTRAL
# Geocoding - 295 PUNGGOL CENTRAL
# Geocoding - 192 PUNGGOL CENTRAL
# Geocoding - 191 PUNGGOL CENTRAL
# Geocoding - 83 COMMONWEALTH CL
# Geocoding - 83 COMMONWEALTH CL
# Geocoding - 81 COMMONWEALTH CL
# Geocoding - 113 COMMONWEALTH CRES
# Geocoding - 83 COMMONWEALTH CL
# Geocoding - 7A COMMONWEALTH AVE
# Geocoding - 447A JALAN KAYU
# Geocoding - 447A JALAN KAYU
# Geocoding - 272C SENGKANG CENTRAL
# Geocoding - 272B SENGKANG CENTRAL
# Geocoding - 271B SENGKANG CENTRAL
# Geocoding - 2 LORONG LEW LIAN
# Geocoding - 1 LORONG LEW LIAN
# Geocoding - 201 SERANGOON CENTRAL
# Geocoding - 143 SERANGOON NORTH AVE 1
# Geocoding - 143 SERANGOON NORTH AVE 1
# Geocoding - 530 SERANGOON NORTH AVE 4
# Geocoding - 518 SERANGOON NORTH AVE 4
# Geocoding - 111 SERANGOON NORTH AVE 1
# Geocoding - 538 SERANGOON NORTH AVE 4
# Geocoding - 141 SERANGOON NORTH AVE 2
# Geocoding - 521 SERANGOON NORTH AVE 4
# Geocoding - 553 SERANGOON NORTH AVE 3
# Geocoding - 208 SERANGOON CENTRAL
# Geocoding - 409 SERANGOON CENTRAL
# Geocoding - 549 SERANGOON NORTH AVE 3
# Geocoding - 532 SERANGOON NORTH AVE 4
# Geocoding - 411 SERANGOON CENTRAL
# Geocoding - 420 SERANGOON CENTRAL
# Geocoding - 416 SERANGOON CENTRAL
# Geocoding - 537 SERANGOON NORTH AVE 4
# Geocoding - 503 TAMPINES CENTRAL 1
# Geocoding - 518A TAMPINES CENTRAL 7
# Geocoding - 518B TAMPINES CENTRAL 7
# Geocoding - 515B TAMPINES CENTRAL 7
# Geocoding - 515A TAMPINES CENTRAL 7
# Geocoding - 518B TAMPINES CENTRAL 7
# Geocoding - 518D TAMPINES CENTRAL 7
# Geocoding - 161 LORONG 1 TOA PAYOH
# Geocoding - 58 LORONG 4 TOA PAYOH
# Geocoding - 55 LORONG 5 TOA PAYOH
# Geocoding - 13 LORONG 7 TOA PAYOH
# Geocoding - 12 LORONG 7 TOA PAYOH
# Geocoding - 234 LORONG 8 TOA PAYOH
# Geocoding - 71 LORONG 4 TOA PAYOH
# Geocoding - 1 LORONG 7 TOA PAYOH
# Geocoding - 34 LORONG 5 TOA PAYOH
# Geocoding - 51 LORONG 6 TOA PAYOH
# Geocoding - 234 LORONG 8 TOA PAYOH
# Geocoding - 169 LORONG 1 TOA PAYOH
# Geocoding - 112 LORONG 1 TOA PAYOH
# Geocoding - 38 LORONG 5 TOA PAYOH
# Geocoding - 125 LORONG 1 TOA PAYOH
# Geocoding - 100 LORONG 1 TOA PAYOH
# Geocoding - 96 LORONG 3 TOA PAYOH
# Geocoding - 157 LORONG 1 TOA PAYOH
# Geocoding - 163 LORONG 1 TOA PAYOH
# Geocoding - 17 LORONG 7 TOA PAYOH
# Geocoding - 1 LORONG 7 TOA PAYOH
# Geocoding - 100 LORONG 1 TOA PAYOH
# Geocoding - 100 LORONG 1 TOA PAYOH
# Geocoding - 118 LORONG 1 TOA PAYOH
# Geocoding - 109 LORONG 1 TOA PAYOH
# Geocoding - 177 TOA PAYOH CENTRAL
# Geocoding - 203 TOA PAYOH NORTH
# Geocoding - 222 LORONG 8 TOA PAYOH
# Geocoding - 226 LORONG 8 TOA PAYOH
# Geocoding - 221 LORONG 8 TOA PAYOH
# Geocoding - 201 TOA PAYOH NORTH
# Geocoding - 200 TOA PAYOH NORTH
# Geocoding - 179 TOA PAYOH CENTRAL
# Geocoding - 142 LORONG 2 TOA PAYOH
# Geocoding - 171 LORONG 1 TOA PAYOH
# Geocoding - 239 LORONG 1 TOA PAYOH
# Geocoding - 10 LORONG 7 TOA PAYOH
# Geocoding - 142 LORONG 2 TOA PAYOH
# Geocoding - 79A TOA PAYOH CENTRAL
# Geocoding - 79E TOA PAYOH CENTRAL
# Geocoding - 146 LORONG 2 TOA PAYOH
# Geocoding - 141 LORONG 2 TOA PAYOH
# Geocoding - 79B TOA PAYOH CENTRAL
# Geocoding - 179 TOA PAYOH CENTRAL
# Geocoding - 97 LORONG 3 TOA PAYOH
# Geocoding - 11 LORONG 8 TOA PAYOH
# Geocoding - 171 LORONG 1 TOA PAYOH
# Geocoding - 147 LORONG 2 TOA PAYOH
# Geocoding - 138B LORONG 1A TOA PAYOH
# Geocoding - 236 LORONG 1 TOA PAYOH
# Geocoding - 303 YISHUN CENTRAL
# Geocoding - 321 YISHUN CENTRAL
# Geocoding - 932 YISHUN CENTRAL 1
# Geocoding - 927 YISHUN CENTRAL 1
# Geocoding - 932 YISHUN CENTRAL 1
# Geocoding - 106 BEDOK NORTH AVE 4
# Geocoding - 104 BEDOK NORTH AVE 4
# Geocoding - 401 BEDOK NORTH AVE 3
# Geocoding - 126 BEDOK NORTH ST 2
# Geocoding - 549 BEDOK NORTH AVE 1
# Geocoding - 74 BEDOK NORTH RD
# Geocoding - 127 BEDOK NORTH ST 2
# Geocoding - 89 BEDOK NORTH ST 4
# Geocoding - 28 NEW UPPER CHANGI RD
# Geocoding - 30 NEW UPPER CHANGI RD
# Geocoding - 532 BEDOK NORTH ST 3
# Geocoding - 100 BEDOK NORTH AVE 4
# Geocoding - 522 BEDOK NORTH AVE 1
# Geocoding - 107 BEDOK NORTH RD
# Geocoding - 116 BEDOK NORTH RD
# Geocoding - 412 BEDOK NORTH AVE 2
# Geocoding - 116 BEDOK NORTH RD
# Geocoding - 202 BEDOK NORTH ST 1
# Geocoding - 401 BEDOK NORTH AVE 3
# Geocoding - 419 BEDOK NORTH ST 1
# Geocoding - 221B BEDOK CENTRAL
# Geocoding - 221B BEDOK CENTRAL
# Geocoding - 121 BEDOK NORTH RD
# Geocoding - 119 BEDOK NORTH RD
# Geocoding - 547 BEDOK NORTH ST 3
# Geocoding - 428 BEDOK NORTH RD
# Geocoding - 130 BEDOK NORTH ST 2
# Geocoding - 532 BEDOK NORTH ST 3
# Geocoding - 524 BEDOK NORTH ST 3
# Geocoding - 90 BEDOK NORTH ST 4
# Geocoding - 518 BEDOK NORTH AVE 2
# Geocoding - 180 BEDOK NORTH RD
# Geocoding - 181 BEDOK NORTH RD
# Geocoding - 120 BEDOK NORTH ST 2
# Geocoding - 140 BEDOK NORTH ST 2
# Geocoding - 61 NEW UPPER CHANGI RD
# Geocoding - 61 NEW UPPER CHANGI RD
# Geocoding - 180 BUKIT BATOK WEST AVE 8
# Geocoding - 507 BUKIT BATOK ST 52
# Geocoding - 324 BUKIT BATOK ST 33
# Geocoding - 506 BUKIT BATOK ST 52
# Geocoding - 425 BUKIT BATOK WEST AVE 2
# Geocoding - 416 BUKIT BATOK WEST AVE 4
# Geocoding - 260 BUKIT BATOK EAST AVE 4
# Geocoding - 504 BUKIT BATOK ST 52
# Geocoding - 178 BUKIT BATOK WEST AVE 8
# Geocoding - 206 BUKIT BATOK ST 21
# Geocoding - 339 BUKIT BATOK ST 34
# Geocoding - 533 BUKIT BATOK ST 51
# Geocoding - 501 BUKIT BATOK ST 52
# Geocoding - 175 BUKIT BATOK WEST AVE 8
# Geocoding - 375 BUKIT BATOK ST 31
# Geocoding - 250 BUKIT BATOK EAST AVE 5
# Geocoding - 127 BUKIT BATOK WEST AVE 6
# Geocoding - 161 BUKIT BATOK ST 11
# Geocoding - 129 BUKIT BATOK WEST AVE 6
# Geocoding - 240 BUKIT BATOK EAST AVE 5
# Geocoding - 235 BUKIT BATOK EAST AVE 5
# Geocoding - 231 BUKIT BATOK EAST AVE 5
# Geocoding - 217 BUKIT BATOK ST 21
# Geocoding - 258 BUKIT BATOK EAST AVE 4
# Geocoding - 207 BUKIT BATOK ST 21
# Geocoding - 337 BUKIT BATOK ST 34
# Geocoding - 336 BUKIT BATOK ST 32
# Geocoding - 329 BUKIT BATOK ST 33
# Geocoding - 267 BUKIT BATOK EAST AVE 4
# Geocoding - 411 BUKIT BATOK WEST AVE 4
# Geocoding - 269 BUKIT BATOK EAST AVE 4
# Geocoding - 283 BUKIT BATOK EAST AVE 3
# Geocoding - 327 BUKIT BATOK ST 33
# Geocoding - 289E BUKIT BATOK ST 25
# Geocoding - 385 BUKIT BATOK WEST AVE 5
# Geocoding - 337 BUKIT BATOK ST 34
# Geocoding - 215 BUKIT BATOK ST 21
# Geocoding - 290E BUKIT BATOK ST 24
# Geocoding - 107 BUKIT BATOK WEST AVE 6
# Geocoding - 171 BUKIT BATOK WEST AVE 8
# Geocoding - 291A BUKIT BATOK ST 24
# Geocoding - 289E BUKIT BATOK ST 25
# Geocoding - 395 BUKIT BATOK WEST AVE 5
# Geocoding - 170 BUKIT BATOK WEST AVE 8
# Geocoding - 108 BUKIT BATOK WEST AVE 6
# Geocoding - 190 BUKIT BATOK WEST AVE 6
# Geocoding - 177 BUKIT BATOK WEST AVE 8
# Geocoding - 289G BUKIT BATOK ST 25
# Geocoding - 131 BUKIT BATOK WEST AVE 6
# Geocoding - 385 BUKIT BATOK WEST AVE 5
# Geocoding - 102 BUKIT BATOK WEST AVE 6
# Geocoding - 625 BUKIT BATOK CENTRAL
# Geocoding - 236 BUKIT BATOK EAST AVE 5
# Geocoding - 291A BUKIT BATOK ST 24
# Geocoding - 290A BUKIT BATOK ST 24
# Geocoding - 390 BUKIT BATOK WEST AVE 5
# Geocoding - 192 BUKIT BATOK WEST AVE 6
# Geocoding - 289D BUKIT BATOK ST 25
# Geocoding - 620 BUKIT BATOK CENTRAL
# Geocoding - 512 BUKIT BATOK ST 52
# Geocoding - 526 BUKIT BATOK ST 51
# Geocoding - 535 BUKIT BATOK ST 52
# Geocoding - 524 BUKIT BATOK ST 52
# Geocoding - 141 BUKIT BATOK ST 11
# Geocoding - 289D BUKIT BATOK ST 25
# Geocoding - 113 JALAN BUKIT MERAH
# Geocoding - 130 BUKIT MERAH VIEW
# Geocoding - 101 BUKIT PURMEI RD
# Geocoding - 142 JALAN BUKIT MERAH
# Geocoding - 101 BUKIT PURMEI RD
# Geocoding - 105 BUKIT PURMEI RD
# Geocoding - 109 JALAN BUKIT MERAH
# Geocoding - 110 BUKIT PURMEI RD
# Geocoding - 40 JALAN RUMAH TINGGI
# Geocoding - 118D JALAN MEMBINA
# Geocoding - 27A JALAN MEMBINA
# Geocoding - 27A JALAN MEMBINA
# Geocoding - 26B JALAN MEMBINA
# Geocoding - 115 BUKIT MERAH CENTRAL
# Geocoding - 9 JALAN RUMAH TINGGI
# Geocoding - 111 BUKIT PURMEI RD
# ...
# Geocoding - 609B TAMPINES NORTH DR 1
# Geocoding - 610B TAMPINES NORTH DR 1
# Geocoding - 608B TAMPINES NORTH DR 1
# Geocoding - 613B TAMPINES NORTH DR 1
# Geocoding - 608B TAMPINES NORTH DR 1
# Geocoding - 610A TAMPINES NORTH DR 1
# Geocoding - 612A TAMPINES NORTH DR 1
# Geocoding - 609A TAMPINES NORTH DR 1
# Geocoding - 610A TAMPINES NORTH DR 1
# Geocoding - 612B TAMPINES NORTH DR 1
# Geocoding - 161 LORONG 1 TOA PAYOH
# Geocoding - 56 LORONG 4 TOA PAYOH
# Geocoding - 54 LORONG 5 TOA PAYOH
# Geocoding - 123 LORONG 1 TOA PAYOH
# Geocoding - 108 LORONG 1 TOA PAYOH
# Geocoding - 131B LORONG 1 TOA PAYOH
# Geocoding - 125 LORONG 1 TOA PAYOH
# Geocoding - 158 LORONG 1 TOA PAYOH
# Geocoding - 100 LORONG 1 TOA PAYOH
# Geocoding - 114 LORONG 1 TOA PAYOH
# Geocoding - 98 LORONG 1 TOA PAYOH
# Geocoding - 130A LORONG 1 TOA PAYOH
# Geocoding - 138A LORONG 1A TOA PAYOH
# Geocoding - 85A LORONG 4 TOA PAYOH
# Geocoding - 85A LORONG 4 TOA PAYOH
# Geocoding - 47 LORONG 6 TOA PAYOH
# Geocoding - 12 LORONG 7 TOA PAYOH
# Geocoding - 1 LORONG 7 TOA PAYOH
# Geocoding - 1 LORONG 7 TOA PAYOH
# Geocoding - 9 LORONG 7 TOA PAYOH
# Geocoding - 12 LORONG 7 TOA PAYOH
# Geocoding - 235 LORONG 8 TOA PAYOH
# Geocoding - 235 LORONG 8 TOA PAYOH
# Geocoding - 225 LORONG 8 TOA PAYOH
# Geocoding - 183 TOA PAYOH CENTRAL
# Geocoding - 205 TOA PAYOH NORTH
# Geocoding - 205 TOA PAYOH NORTH
# Geocoding - 207 TOA PAYOH NORTH
# Geocoding - 205 TOA PAYOH NORTH
# Geocoding - 205 TOA PAYOH NORTH
# Geocoding - 7 UPPER ALJUNIED LANE
# Geocoding - 130A LORONG 1 TOA PAYOH
# Geocoding - 131A LORONG 1 TOA PAYOH
# Geocoding - 238 LORONG 1 TOA PAYOH
# Geocoding - 130B LORONG 1 TOA PAYOH
# Geocoding - 139A LORONG 1A TOA PAYOH
# Geocoding - 145 LORONG 2 TOA PAYOH
# Geocoding - 144 LORONG 2 TOA PAYOH
# Geocoding - 147 LORONG 2 TOA PAYOH
# Geocoding - 84B LORONG 2 TOA PAYOH
# Geocoding - 145 LORONG 2 TOA PAYOH
# Geocoding - 11 LORONG 8 TOA PAYOH
# Geocoding - 214 LORONG 8 TOA PAYOH
# Geocoding - 219 LORONG 8 TOA PAYOH
# Geocoding - 214 LORONG 8 TOA PAYOH
# Geocoding - 219 LORONG 8 TOA PAYOH
# Geocoding - 79E TOA PAYOH CENTRAL
# Geocoding - 79B TOA PAYOH CENTRAL
# Geocoding - 171 LORONG 1 TOA PAYOH
# Geocoding - 138A LORONG 1A TOA PAYOH
# Geocoding - 138B LORONG 1A TOA PAYOH
# Geocoding - 138A LORONG 1A TOA PAYOH
# Geocoding - 139A LORONG 1A TOA PAYOH
# Geocoding - 144 LORONG 2 TOA PAYOH
# Geocoding - 143 LORONG 2 TOA PAYOH
# Geocoding - 154 LORONG 2 TOA PAYOH
# Geocoding - 35 LORONG 5 TOA PAYOH
# Geocoding - 229 LORONG 8 TOA PAYOH
# Geocoding - 321 YISHUN CENTRAL
# Geocoding - 424D YISHUN AVE 11
# Geocoding - 320 YISHUN CENTRAL
# Geocoding - 932 YISHUN CENTRAL 1
# Geocoding - 302 YISHUN CENTRAL
# Geocoding - 927 YISHUN CENTRAL 1
# Geocoding - 90 BEDOK NORTH ST 4
# Geocoding - 541 BEDOK NORTH ST 3
# Geocoding - 220A BEDOK CENTRAL
# Geocoding - 550 BEDOK NORTH AVE 1
# Geocoding - 550 BEDOK NORTH AVE 1
# Geocoding - 550 BEDOK NORTH AVE 1
# Geocoding - 515 BEDOK NORTH AVE 2
# Geocoding - 105 BEDOK NORTH AVE 4
# Geocoding - 116 BEDOK NORTH RD
# Geocoding - 116 BEDOK NORTH RD
# Geocoding - 129 BEDOK NORTH ST 2
# Geocoding - 525 BEDOK NORTH ST 3
# Geocoding - 510 BEDOK NORTH ST 3
# Geocoding - 534 BEDOK NORTH ST 3
# Geocoding - 510 BEDOK NORTH ST 3
# Geocoding - 530 BEDOK NORTH ST 3
# Geocoding - 501 BEDOK NORTH ST 3
# Geocoding - 532 BEDOK NORTH ST 3
# Geocoding - 188D BEDOK NORTH ST 4
# Geocoding - 84 BEDOK NORTH ST 4
# Geocoding - 29 NEW UPPER CHANGI RD
# Geocoding - 57 NEW UPPER CHANGI RD
# Geocoding - 27 NEW UPPER CHANGI RD
# Geocoding - 28 NEW UPPER CHANGI RD
# Geocoding - 30 NEW UPPER CHANGI RD
# Geocoding - 221C BEDOK CENTRAL
# Geocoding - 521 BEDOK NORTH AVE 1
# Geocoding - 423 BEDOK NORTH AVE 1
# Geocoding - 411 BEDOK NORTH AVE 2
# Geocoding - 512 BEDOK NORTH AVE 2
# Geocoding - 133 BEDOK NORTH AVE 3
# Geocoding - 95 BEDOK NORTH AVE 4
# Geocoding - 427 BEDOK NORTH RD
# Geocoding - 422 BEDOK NORTH RD
# Geocoding - 128 BEDOK NORTH ST 2
# Geocoding - 127 BEDOK NORTH ST 2
# Geocoding - 543 BEDOK NORTH ST 3
# Geocoding - 187B BEDOK NORTH ST 4
# Geocoding - 186A BEDOK NORTH ST 4
# Geocoding - 187B BEDOK NORTH ST 4
# Geocoding - 186B BEDOK NORTH ST 4
# Geocoding - 414 BEDOK NORTH AVE 2
# Geocoding - 414 BEDOK NORTH AVE 2
# Geocoding - 97 BEDOK NORTH AVE 4
# Geocoding - 140 BEDOK NORTH ST 2
# Geocoding - 187B BEDOK NORTH ST 4
# Geocoding - 187B BEDOK NORTH ST 4
# Geocoding - 54 NEW UPPER CHANGI RD
# Geocoding - 435B BUKIT BATOK WEST AVE 5
# Geocoding - 435B BUKIT BATOK WEST AVE 5
# Geocoding - 451A BUKIT BATOK WEST AVE 6
# Geocoding - 438A BUKIT BATOK WEST AVE 8
# Geocoding - 438A BUKIT BATOK WEST AVE 8
# Geocoding - 438A BUKIT BATOK WEST AVE 8
# Geocoding - 460A BUKIT BATOK WEST AVE 9
# Geocoding - 460D BUKIT BATOK WEST AVE 9
# Geocoding - 225 BUKIT BATOK CENTRAL
# Geocoding - 225 BUKIT BATOK CENTRAL
# Geocoding - 230 BUKIT BATOK EAST AVE 3
# Geocoding - 271 BUKIT BATOK EAST AVE 4
# Geocoding - 260 BUKIT BATOK EAST AVE 4
# Geocoding - 269 BUKIT BATOK EAST AVE 4
# Geocoding - 239 BUKIT BATOK EAST AVE 5
# Geocoding - 163 BUKIT BATOK ST 11
# Geocoding - 208 BUKIT BATOK ST 21
# Geocoding - 333 BUKIT BATOK ST 32
# Geocoding - 327 BUKIT BATOK ST 33
# Geocoding - 324 BUKIT BATOK ST 33
# Geocoding - 343 BUKIT BATOK ST 34
# Geocoding - 533 BUKIT BATOK ST 51
# Geocoding - 528 BUKIT BATOK ST 51
# Geocoding - 505 BUKIT BATOK ST 52
# Geocoding - 505 BUKIT BATOK ST 52
# Geocoding - 506 BUKIT BATOK ST 52
# Geocoding - 422 BUKIT BATOK WEST AVE 2
# Geocoding - 409 BUKIT BATOK WEST AVE 4
# Geocoding - 410 BUKIT BATOK WEST AVE 4
# Geocoding - 410 BUKIT BATOK WEST AVE 4
# Geocoding - 411 BUKIT BATOK WEST AVE 4
# Geocoding - 435B BUKIT BATOK WEST AVE 5
# Geocoding - 450A BUKIT BATOK WEST AVE 6
# Geocoding - 146 BUKIT BATOK WEST AVE 6
# Geocoding - 136 BUKIT BATOK WEST AVE 6
# Geocoding - 135 BUKIT BATOK WEST AVE 6
# Geocoding - 194B BUKIT BATOK WEST AVE 6
# Geocoding - 139 BUKIT BATOK WEST AVE 6
# Geocoding - 148 BUKIT BATOK WEST AVE 6
# Geocoding - 148 BUKIT BATOK WEST AVE 6
# Geocoding - 438B BUKIT BATOK WEST AVE 8
# Geocoding - 169 BUKIT BATOK WEST AVE 8
# Geocoding - 272 BUKIT BATOK EAST AVE 4
# Geocoding - 292B BUKIT BATOK EAST AVE 6
# Geocoding - 293C BUKIT BATOK ST 21
# Geocoding - 293C BUKIT BATOK ST 21
# Geocoding - 293D BUKIT BATOK ST 21
# Geocoding - 208 BUKIT BATOK ST 21
# Geocoding - 293B BUKIT BATOK ST 21
# Geocoding - 290A BUKIT BATOK ST 24
# Geocoding - 290G BUKIT BATOK ST 24
# Geocoding - 289F BUKIT BATOK ST 25
# Geocoding - 288C BUKIT BATOK ST 25
# Geocoding - 288C BUKIT BATOK ST 25
# Geocoding - 289E BUKIT BATOK ST 25
# Geocoding - 308 BUKIT BATOK ST 31
# Geocoding - 304 BUKIT BATOK ST 31
# Geocoding - 318 BUKIT BATOK ST 32
# Geocoding - 325 BUKIT BATOK ST 33
# Geocoding - 325 BUKIT BATOK ST 33
# Geocoding - 338 BUKIT BATOK ST 34
# Geocoding - 346 BUKIT BATOK ST 34
# Geocoding - 421 BUKIT BATOK WEST AVE 2
# Geocoding - 411 BUKIT BATOK WEST AVE 4
# Geocoding - 437A BUKIT BATOK WEST AVE 5
# Geocoding - 392 BUKIT BATOK WEST AVE 5
# Geocoding - 384 BUKIT BATOK WEST AVE 5
# Geocoding - 391 BUKIT BATOK WEST AVE 5
# Geocoding - 435C BUKIT BATOK WEST AVE 5
# Geocoding - 113 BUKIT BATOK WEST AVE 6
# Geocoding - 194A BUKIT BATOK WEST AVE 6
# Geocoding - 451B BUKIT BATOK WEST AVE 6
# Geocoding - 450B BUKIT BATOK WEST AVE 6
# Geocoding - 118 BUKIT BATOK WEST AVE 6
# Geocoding - 453A BUKIT BATOK WEST AVE 6
# Geocoding - 452A BUKIT BATOK WEST AVE 6
# Geocoding - 165 BUKIT BATOK WEST AVE 8
# Geocoding - 461D BUKIT BATOK WEST AVE 8
# Geocoding - 438C BUKIT BATOK WEST AVE 8
# Geocoding - 441A BUKIT BATOK WEST AVE 8
# Geocoding - 439B BUKIT BATOK WEST AVE 8
# Geocoding - 439C BUKIT BATOK WEST AVE 8
# Geocoding - 439B BUKIT BATOK WEST AVE 8
# Geocoding - 449A BUKIT BATOK WEST AVE 9
# Geocoding - 449B BUKIT BATOK WEST AVE 9
# Geocoding - 449A BUKIT BATOK WEST AVE 9
# Geocoding - 622 BUKIT BATOK CENTRAL
# Geocoding - 201 BUKIT BATOK ST 21
# Geocoding - 296C BUKIT BATOK ST 22
# Geocoding - 290E BUKIT BATOK ST 24
# Geocoding - 315 BUKIT BATOK ST 32
# Geocoding - 511 BUKIT BATOK ST 52
# Geocoding - 426 BUKIT BATOK WEST AVE 2
# Geocoding - 393 BUKIT BATOK WEST AVE 5
# Geocoding - 435C BUKIT BATOK WEST AVE 5
# Geocoding - 435C BUKIT BATOK WEST AVE 5
# Geocoding - 394 BUKIT BATOK WEST AVE 5
# Geocoding - 110 BUKIT BATOK WEST AVE 6
# Geocoding - 194A BUKIT BATOK WEST AVE 6
# Geocoding - 443A BUKIT BATOK WEST AVE 8
# Geocoding - 439B BUKIT BATOK WEST AVE 8
# Geocoding - 461C BUKIT BATOK WEST AVE 8
# Geocoding - 440C BUKIT BATOK WEST AVE 8
# Geocoding - 442A BUKIT BATOK WEST AVE 8
# Geocoding - 440D BUKIT BATOK WEST AVE 8
# Geocoding - 172 BUKIT BATOK WEST AVE 8
# Geocoding - 221 BUKIT BATOK EAST AVE 3
# Geocoding - 287 BUKIT BATOK EAST AVE 3
# Geocoding - 290B BUKIT BATOK ST 24
# Geocoding - 288B BUKIT BATOK ST 25
# Geocoding - 330 BUKIT BATOK ST 33
# Geocoding - 330 BUKIT BATOK ST 33
# Geocoding - 512 BUKIT BATOK ST 52
# Geocoding - 512 BUKIT BATOK ST 52
# Geocoding - 119 BUKIT MERAH VIEW
# Geocoding - 130 BUKIT MERAH VIEW
# Geocoding - 130 BUKIT MERAH VIEW
# Geocoding - 2 JALAN BUKIT MERAH
# Geocoding - 137 JALAN BUKIT MERAH
# Geocoding - 26A JALAN MEMBINA
# Geocoding - 120 BUKIT MERAH VIEW
# Geocoding - 110 BUKIT PURMEI RD
# Geocoding - 114 BUKIT PURMEI RD
# Geocoding - 146 JALAN BUKIT MERAH
# Geocoding - 144 JALAN BUKIT MERAH
# Geocoding - 26C JALAN MEMBINA
# Geocoding - 20 JALAN MEMBINA
# Geocoding - 26D JALAN MEMBINA
# Geocoding - 26D JALAN MEMBINA
# Geocoding - 26D JALAN MEMBINA
# Geocoding - 40 JALAN RUMAH TINGGI
# Geocoding - 13 JALAN BUKIT MERAH
# Geocoding - 243 BUKIT PANJANG RING RD
# Geocoding - 243 BUKIT PANJANG RING RD
# Geocoding - 430 BUKIT PANJANG RING RD
# Geocoding - 537 BUKIT PANJANG RING RD
# Geocoding - 430 BUKIT PANJANG RING RD
# Geocoding - 240 BUKIT PANJANG RING RD
# Geocoding - 620 BUKIT PANJANG RING RD
# Geocoding - 449 BUKIT PANJANG RING RD
# Geocoding - 611 BUKIT PANJANG RING RD
# Geocoding - 448 BUKIT PANJANG RING RD
# Geocoding - 259 BUKIT PANJANG RING RD
# Geocoding - 239 BUKIT PANJANG RING RD
# Geocoding - 538 UPPER CROSS ST
# Geocoding - 220 CHOA CHU KANG CENTRAL
# Geocoding - 210 CHOA CHU KANG CENTRAL
# Geocoding - 215 CHOA CHU KANG CENTRAL
# Geocoding - 354 CHOA CHU KANG CENTRAL
# Geocoding - 763 CHOA CHU KANG NORTH 5
# Geocoding - 229 CHOA CHU KANG CENTRAL
# Geocoding - 236 CHOA CHU KANG CENTRAL
# Geocoding - 751 CHOA CHU KANG NORTH 5
# Geocoding - 617 CHOA CHU KANG NORTH 7
# Geocoding - 618 CHOA CHU KANG NORTH 7
# Geocoding - 155 JALAN TECK WHYE
# Geocoding - 156 JALAN TECK WHYE
# Geocoding - 163 JALAN TECK WHYE
# Geocoding - 410 COMMONWEALTH AVE WEST
# Geocoding - 93 JALAN DUA
# Geocoding - 365B UPPER SERANGOON RD
# Geocoding - 476A UPPER SERANGOON VIEW
# Geocoding - 836 HOUGANG CENTRAL
# Geocoding - 143 LORONG AH SOO
# Geocoding - 142 LORONG AH SOO
# Geocoding - 475D UPPER SERANGOON CRES
# Geocoding - 464 UPPER SERANGOON RD
# Geocoding - 365A UPPER SERANGOON RD
# Geocoding - 476A UPPER SERANGOON VIEW
# Geocoding - 837 HOUGANG CENTRAL
# Geocoding - 139 LORONG AH SOO
# Geocoding - 470B UPPER SERANGOON CRES
# Geocoding - 679C JURONG WEST CENTRAL 1
# Geocoding - 686C JURONG WEST CENTRAL 1
# Geocoding - 163 YUNG PING RD
# Geocoding - 49 JALAN BAHAGIA
# Geocoding - 117A JALAN TENTERAM
# Geocoding - 76 LORONG LIMAU
# Geocoding - 77 LORONG LIMAU
# Geocoding - 11 UPPER BOON KENG RD
# Geocoding - 5A UPPER BOON KENG RD
# Geocoding - 8B UPPER BOON KENG RD
# Geocoding - 101 JALAN RAJAH
# Geocoding - 117B JALAN TENTERAM
# Geocoding - 116A JALAN TENTERAM
# Geocoding - 116A JALAN TENTERAM
# Geocoding - 2A UPPER BOON KENG RD
# Geocoding - 3B UPPER BOON KENG RD
# Geocoding - 2A UPPER BOON KENG RD
# Geocoding - 2D UPPER BOON KENG RD
# Geocoding - 8A UPPER BOON KENG RD
# Geocoding - 623B PUNGGOL CENTRAL
# Geocoding - 622C PUNGGOL CENTRAL
# Geocoding - 622A PUNGGOL CENTRAL
# Geocoding - 162A PUNGGOL CENTRAL
# Geocoding - 624A PUNGGOL CENTRAL
# Geocoding - 301C PUNGGOL CENTRAL
# Geocoding - 624A PUNGGOL CENTRAL
# Geocoding - 163A PUNGGOL CENTRAL
# Geocoding - 162B PUNGGOL CENTRAL
# Geocoding - 647 PUNGGOL CENTRAL
# Geocoding - 192 PUNGGOL CENTRAL
# Geocoding - 191 PUNGGOL CENTRAL
# Geocoding - 83 COMMONWEALTH CL
# Geocoding - 82 COMMONWEALTH CL
# Geocoding - 99 COMMONWEALTH CRES
# Geocoding - 81 COMMONWEALTH CL
# Geocoding - 85 COMMONWEALTH CL
# Geocoding - 83 COMMONWEALTH CL
# Geocoding - 83 COMMONWEALTH CL
# Geocoding - 99 COMMONWEALTH CRES
# Geocoding - 91 COMMONWEALTH DR
# Geocoding - 7A COMMONWEALTH AVE
# Geocoding - 446C JALAN KAYU
# Geocoding - 271A SENGKANG CENTRAL
# Geocoding - 1 LORONG LEW LIAN
# Geocoding - 206 SERANGOON CENTRAL
# Geocoding - 206 SERANGOON CENTRAL
# Geocoding - 207 SERANGOON CENTRAL
# Geocoding - 105 SERANGOON NORTH AVE 1
# Geocoding - 102 SERANGOON NORTH AVE 1
# Geocoding - 108 SERANGOON NORTH AVE 1
# Geocoding - 126 SERANGOON NORTH AVE 1
# Geocoding - 103 SERANGOON NORTH AVE 1
# Geocoding - 109 SERANGOON NORTH AVE 1
# Geocoding - 145 SERANGOON NORTH AVE 1
# Geocoding - 411 SERANGOON CENTRAL
# Geocoding - 257 SERANGOON CENTRAL DR
# Geocoding - 140 SERANGOON NORTH AVE 2
# Geocoding - 137 SERANGOON NORTH AVE 2
# Geocoding - 543 SERANGOON NORTH AVE 3
# Geocoding - 520 SERANGOON NORTH AVE 4
# Geocoding - 537 SERANGOON NORTH AVE 4
# Geocoding - 539 SERANGOON NORTH AVE 4
# Geocoding - 499B TAMPINES AVE 9
# Geocoding - 524B TAMPINES CENTRAL 7
# Geocoding - 499B TAMPINES AVE 9
# Geocoding - 613A TAMPINES NORTH DR 1
# Geocoding - 609C TAMPINES NORTH DR 1
# Geocoding - 608C TAMPINES NORTH DR 1
# Geocoding - 609C TAMPINES NORTH DR 1
# Geocoding - 608C TAMPINES NORTH DR 1
# Geocoding - 508 TAMPINES CENTRAL 1
# Geocoding - 522A TAMPINES CENTRAL 7
# Geocoding - 523A TAMPINES CENTRAL 7
# Geocoding - 519C TAMPINES CENTRAL 8
# Geocoding - 609A TAMPINES NORTH DR 1
# Geocoding - 608C TAMPINES NORTH DR 1
# Geocoding - 613B TAMPINES NORTH DR 1
# Geocoding - 608B TAMPINES NORTH DR 1
# Geocoding - 610B TAMPINES NORTH DR 1
# Geocoding - 610A TAMPINES NORTH DR 1
# Geocoding - 613B TAMPINES NORTH DR 1
# Geocoding - 610A TAMPINES NORTH DR 1
# Geocoding - 613B TAMPINES NORTH DR 1
# Geocoding - 608B TAMPINES NORTH DR 1
# Geocoding - 614A TAMPINES NORTH DR 1
# Geocoding - 608A TAMPINES NORTH DR 1
# Geocoding - 518C TAMPINES CENTRAL 7
# Geocoding - 515D TAMPINES CENTRAL 7
# Geocoding - 522C TAMPINES CENTRAL 7
# Geocoding - 519B TAMPINES CENTRAL 8
# Geocoding - 519D TAMPINES CENTRAL 8
# Geocoding - 613B TAMPINES NORTH DR 1
# Geocoding - 610A TAMPINES NORTH DR 1
# Geocoding - 609B TAMPINES NORTH DR 1
# Geocoding - 610A TAMPINES NORTH DR 1
# Geocoding - 612B TAMPINES NORTH DR 1
# Geocoding - 610C TAMPINES NORTH DR 1
# Geocoding - 610B TAMPINES NORTH DR 1
# Geocoding - 609A TAMPINES NORTH DR 1
# Geocoding - 610C TAMPINES NORTH DR 1
# Geocoding - 608B TAMPINES NORTH DR 1
# Geocoding - 120 LORONG 2 TOA PAYOH
# Geocoding - 51 LORONG 6 TOA PAYOH
# Geocoding - 123 LORONG 1 TOA PAYOH
# Geocoding - 126 LORONG 1 TOA PAYOH
# Geocoding - 119 LORONG 1 TOA PAYOH
# Geocoding - 100 LORONG 1 TOA PAYOH
# Geocoding - 125 LORONG 1 TOA PAYOH
# Geocoding - 157 LORONG 1 TOA PAYOH
# Geocoding - 131B LORONG 1 TOA PAYOH
# Geocoding - 116 LORONG 2 TOA PAYOH
# Geocoding - 73 LORONG 4 TOA PAYOH
# Geocoding - 94 LORONG 4 TOA PAYOH
# Geocoding - 53 LORONG 5 TOA PAYOH
# Geocoding - 53 LORONG 5 TOA PAYOH
# Geocoding - 47 LORONG 6 TOA PAYOH
# Geocoding - 17 LORONG 7 TOA PAYOH
# Geocoding - 12 LORONG 7 TOA PAYOH
# Geocoding - 12 LORONG 7 TOA PAYOH
# Geocoding - 13 LORONG 7 TOA PAYOH
# Geocoding - 207 TOA PAYOH NORTH
# Geocoding - 3 UPPER ALJUNIED LANE
# Geocoding - 130A LORONG 1 TOA PAYOH
# Geocoding - 138B LORONG 1A TOA PAYOH
# Geocoding - 84 LORONG 2 TOA PAYOH
# Geocoding - 141 LORONG 2 TOA PAYOH
# Geocoding - 81A LORONG 4 TOA PAYOH
# Geocoding - 80B LORONG 4 TOA PAYOH
# Geocoding - 10B LORONG 7 TOA PAYOH
# Geocoding - 222 LORONG 8 TOA PAYOH
# Geocoding - 219 LORONG 8 TOA PAYOH
# Geocoding - 213 LORONG 8 TOA PAYOH
# Geocoding - 222 LORONG 8 TOA PAYOH
# Geocoding - 221 LORONG 8 TOA PAYOH
# Geocoding - 222 LORONG 8 TOA PAYOH
# Geocoding - 79E TOA PAYOH CENTRAL
# Geocoding - 79A TOA PAYOH CENTRAL
# Geocoding - 79A TOA PAYOH CENTRAL
# Geocoding - 79D TOA PAYOH CENTRAL
# Geocoding - 79B TOA PAYOH CENTRAL
# Geocoding - 172 LORONG 1 TOA PAYOH
# Geocoding - 138B LORONG 1A TOA PAYOH
# Geocoding - 139A LORONG 1A TOA PAYOH
# Geocoding - 138B LORONG 1A TOA PAYOH
# Geocoding - 138C LORONG 1A TOA PAYOH
# Geocoding - 142 LORONG 2 TOA PAYOH
# Geocoding - 152 LORONG 2 TOA PAYOH
# Geocoding - 97 LORONG 3 TOA PAYOH
# Geocoding - 44 LORONG 5 TOA PAYOH
# Geocoding - 44 LORONG 5 TOA PAYOH
# Geocoding - 6 LORONG 7 TOA PAYOH
# Geocoding - 14A LORONG 7 TOA PAYOH
# Geocoding - 14A LORONG 7 TOA PAYOH
# Geocoding - 424D YISHUN AVE 11
# Geocoding - 502C YISHUN ST 51
# Geocoding - 502C YISHUN ST 51
# Geocoding - 502C YISHUN ST 51
# Geocoded dataset saved as: HDBResale_with_coordinates.csv

# %%
import pandas as pd

# Load dataset
file_path = "HDBResale_with_coordinates.csv"  # Adjust if needed
df = pd.read_csv(file_path)

# Ensure Latitude and Longitude columns exist
if "Latitude" not in df.columns or "Longitude" not in df.columns:
    raise ValueError("Dataset must contain 'Latitude' and 'Longitude' columns.")

# Filter rows where either Latitude or Longitude is missing
missing_coords_df = df[df["Latitude"].isna() | df["Longitude"].isna()]

# Save to a new CSV file
output_file = "Missing_Coordinates.csv"
missing_coords_df.to_csv(output_file, index=False)

print(f"Rows with missing coordinates saved as: {output_file}")
# Out:
# Rows with missing coordinates saved as: Missing_Coordinates.csv

# %% [markdown]
# ### Feature Engineering - Number of location within 1km ###

# %% [markdown]
# 1. Run files feature_engineering-complex_coordinates.py and feature_engineering.py to computed the number of each type of location within a 1km radius of every property.
#
# 2. Merge datasets

# %%
import pandas as pd

# Load datasets
data = pd.read_csv("Data/data_simple.csv")
data_ltamrt = pd.read_csv("Data/data_complex_LTAMRTStation.csv")
data_nparks = pd.read_csv("Data/data_complex_NParks.csv")

# Merge datasets on common columns
data_merged = data.merge(
    data_ltamrt[["month", "year", 'town', 'flat_type', 'block', 'street_name', 'LTAMRTStation_within_1km', 'LTAMRTStation_nearest']],
    on=["month", "year", 'town', 'flat_type', 'block', 'street_name'],
    how='left'
).merge(
    data_nparks[["month", "year", 'town', 'flat_type', 'block', 'street_name', 'NParks_within_1km', 'NParks_nearest']],
    on=["month", "year", 'town', 'flat_type', 'block', 'street_name'],
    how='left'
)

# Reorder columns
final_columns = [
    "month", "year", "town", "town_LE", "town_TE","flat_type",  "flat_type_LE", "flat_type_TE", "block", "street_name", 
    "storey_range", "storey_range_LE", "floor_area_sqm", "price_per_sqm", "flat_model",  "flat_model_LE", "flat_model_TE",
    "lease_commence_date", "remaining_lease", "resale_price", "Latitude", "Longitude", 
    "LTAMRTStation_within_1km", "LTAMRTStation_nearest", "MallCoordinates_within_1km", "MallCoordinates_nearest", 
    "Hawker_within_1km", "Hawker_nearest", "PreSchool_within_1km", "PreSchool_nearest", 
    "Primary_within_1km", "Primary_nearest", "Secondary_within_1km", "Secondary_nearest", 
    "JuniorCollege_within_1km", "JuniorCollege_nearest", "MixedLevel_within_1km", "MixedLevel_nearest", 
    "NParks_within_1km", "NParks_nearest", "Sports_within_1km", "Sports_nearest"
]
data_merged = data_merged[final_columns]

# Save to CSV
data_merged.to_csv("Data/data.csv", index=False)

# Display first few rows
data_merged.head()

# %% [markdown]
# ### Splitting Data ###

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load both datasets
cleaned_df = pd.read_csv("Data/cleaned_data.csv")  # Cleaned data
normalized_df = pd.read_csv("Data/cleaned_data_normalisation.csv")  # Normalized data

# Ensure the same order in both datasets
assert cleaned_df.shape == normalized_df.shape, "Datasets have different shapes!"
assert (cleaned_df.columns == normalized_df.columns).all(), "Columns do not match!"
assert (cleaned_df.index == normalized_df.index).all(), "Indexes do not match!"

# Define target variable
target_column = "resale_price"

# Create an index column to ensure consistent splitting
cleaned_df["index"] = cleaned_df.index  # Create index reference
normalized_df["index"] = normalized_df.index  # Keep the same index

# Split only the cleaned dataset (train-test split based on indices)
train_idx, test_idx = train_test_split(cleaned_df["index"], test_size=0.2, random_state=42)

# Use the same indices to split both datasets
cleaned_train = cleaned_df.loc[train_idx].drop(columns=["index"])
cleaned_test = cleaned_df.loc[test_idx].drop(columns=["index"])
normalized_train = normalized_df.loc[train_idx].drop(columns=["index"])
normalized_test = normalized_df.loc[test_idx].drop(columns=["index"])

# Save the consistent train/test splits for both datasets
cleaned_train.to_csv("Data/cleaned_train.csv", index=False)
cleaned_test.to_csv("Data/cleaned_test.csv", index=False)
normalized_train.to_csv("Data/normalized_train.csv", index=False)
normalized_test.to_csv("Data/normalized_test.csv", index=False)

# ✅ Check if month, year, town, block, and street_name are the same across both datasets
columns_to_check = ["month", "year", "town", "block", "street_name"]

train_check = cleaned_train[columns_to_check].equals(normalized_train[columns_to_check])
test_check = cleaned_test[columns_to_check].equals(normalized_test[columns_to_check])

if train_check and test_check:
    print("✅ The train and test sets are consistent across cleaned and normalized datasets.")
else:
    print("❌ Inconsistency detected in train/test splits. Check data alignment!")

print("✅ Training and test datasets are consistently split and saved as CSVs!")

# %% [markdown]
# ### Data Analysis ###

# %%
import folium
import pandas as pd
from folium.plugins import MarkerCluster

# Load dataset
df = pd.read_csv("Data/cleaned_train.csv")

# Remove missing values
df = df.dropna(subset=["Latitude", "Longitude", "resale_price"])

# Group by location and compute average resale price and count of transactions
grouped = df.groupby(["Latitude", "Longitude"], as_index=False).agg(
    avg_price=("resale_price", "mean"), count=("resale_price", "count")
)

# Create a map centered on Singapore
singapore_map_cluster = folium.Map(location=[1.3521, 103.8198], zoom_start=12)

# Get the correct map variable name assigned by Folium
map_var_name = singapore_map_cluster.get_name()

# Create a marker cluster
marker_cluster = MarkerCluster().add_to(singapore_map_cluster)

# Add markers to the cluster
for _, row in grouped.iterrows():
    folium.Marker(
        location=[row["Latitude"], row["Longitude"]],
        popup=f"Avg Resale Price: ${row['avg_price']:,.2f} ({int(row['count'])} units)",
        tooltip=f"Avg Resale Price: ${row['avg_price']:,.2f} ({int(row['count'])} units)",
        icon=folium.Icon(color="blue", icon="info-sign"),
    ).add_to(marker_cluster)

# JavaScript for adding cluster hover tooltips
custom_js = f'''
<script>
document.addEventListener("DOMContentLoaded", function() {{
    var actualMap = { map_var_name };  // Correct map variable

    actualMap.eachLayer(function(layer) {{
        if (layer instanceof L.MarkerClusterGroup) {{
            console.log("Cluster layer detected!");  // Debugging

            layer.on("clustermouseover", function(e) {{
                console.log("Hover event fired!!!", e.layer);

                var cluster = e.layer;
                var totalPrice = 0;
                var totalCount = 0;

                // Recursively get only clustered markers
                function getMarkersInCluster(clusterLayer) {{
                    var markers = clusterLayer._markers || [];  // Directly inside this cluster

                    if (clusterLayer._childClusters && clusterLayer._childClusters.length > 0) {{
                        clusterLayer._childClusters.forEach(childCluster => {{
                            markers = markers.concat(getMarkersInCluster(childCluster)); // Collect markers from child clusters
                        }});
                    }}

                    return markers;
                }}

                var clusterMarkers = getMarkersInCluster(cluster);
                console.log("Total Cluster Markers Found:", clusterMarkers.length);

                // Separate pin markers (standalone markers outside clusters)
                var pinMarkers = [];
                actualMap.eachLayer(function(layer) {{
                    if (layer instanceof L.Marker && !layer.__parent) {{  // Exclude cluster markers
                        pinMarkers.push(layer);
                    }}
                }});

                // Merge both cluster markers and pin markers
                var allMarkers = clusterMarkers.concat(pinMarkers);
                console.log("Total Markers to Process:", allMarkers.length);

                if (allMarkers.length === 0) {{
                    console.warn("No visible markers found, skipping popup.");
                    return;
                }}

                // Debug: Check marker popups
                allMarkers.forEach(marker => {{
                    console.log("Checking marker:", marker);
                    console.log("Popup content:", marker.getPopup() ? marker.getPopup().getContent() : "No popup found");
                }});

                // Convert popup content to plain text (strip HTML tags if needed)
                function extractTextFromPopup(popupContent) {{
                    if (typeof popupContent === "string") {{
                        return popupContent.trim(); // Already plain text, trim spaces
                    }} else if (popupContent instanceof HTMLElement) {{
                        return (popupContent.textContent || popupContent.innerText || "").trim(); // Extract text from HTML element
                    }} else {{
                        console.warn("Unexpected popup content type:", popupContent);
                        return "";
                    }}
                }}

                // Process each marker to compute the avg resale price
                var validMarkers = allMarkers.filter(marker => marker instanceof L.Marker && marker.getPopup());

                if (validMarkers.length === 0) {{
                    console.warn("No valid resale price markers found, skipping popup.");
                    return;
                }}

                validMarkers.forEach(marker => {{
                    var popup = marker.getPopup();
                    if (popup) {{
                        var popupText = extractTextFromPopup(popup.getContent()); // Fix: Properly extract text

                        if (typeof popupText === "string") {{
                            var match = popupText.match(/\\$([\\d,]+\\.?\d{{0,2}})/);
                            var countMatch = popupText.match(/\\((\\d+\\.?\\d*) units\\)/);

                            if (match && countMatch) {{
                                var price = parseFloat(match[1].replace(/,/g, "")) || 0;
                                var count = parseFloat(countMatch[1]) || 0;

                                if (!isNaN(price) && !isNaN(count) && count > 0) {{
                                    totalPrice += price * count;
                                    totalCount += count;
                                }} else {{
                                    console.warn("Skipping invalid price/count values:", price, count);
                                }}
                            }}
                        }}
                    }}
                }});

                if (totalCount > 0) {{
                    var avgPrice = (totalPrice / totalCount).toFixed(2);
                    
                    // Format totalCount: Remove `.0` if it's a whole number
                    var formattedTotalCount = (totalCount % 1 === 0) ? totalCount.toFixed(0) : totalCount.toFixed(2);

                    var popup = L.popup({{
                        closeButton: false,
                        autoClose: false,
                        closeOnClick: false,
                        className: "custom-cluster-tooltip"
                    }})
                    .setContent(
                        "<b>Avg Resale Price: $" + avgPrice + "</b><br>" +
                        "<b>Total Units: " + formattedTotalCount + "</b>"
                    )
                    .setLatLng(cluster.getLatLng());

                    popup.openOn(actualMap);

                    // **Immediate Popup Disappearance on Mouseout**
                    cluster.on("mouseout", function() {{
                        actualMap.closePopup();
                    }});
                }} else {{
                    console.warn("No valid resale prices found, popup not created.");
                }}
            }});
        }}
    }});
}});
</script>
'''

# Attach the custom JavaScript to the map
singapore_map_cluster.get_root().html.add_child(folium.Element(custom_js))

# Save and view
singapore_map_cluster.save("singapore_clustered_avg_hover.html")
print("Clustered resale price map with hover popups saved as singapore_clustered_avg_hover.html")
# Out:
# <>:166: SyntaxWarning: invalid escape sequence '\d'
# <>:166: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5412\2085244557.py:166: SyntaxWarning: invalid escape sequence '\d'
#   '''
# Clustered resale price map with hover popups saved as singapore_clustered_avg_hover.html
